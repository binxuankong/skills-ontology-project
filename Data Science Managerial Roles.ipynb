# %%
import pandas as pd
import re
from datetime import datetime as dt
from sqlalchemy import create_engine
from secrets import secrets
from skill_api import extract_skills, extract_ignore

# %%
# Skills
df_skills = pd.read_csv('skills_db2/skill.csv')
SKILLS = df_skills['Skill'].unique().tolist()
# Redundant skills
df_redskills = pd.read_excel('skills/Other Skills.xlsx')
RED_SKILLS = df_redskills['Skill'].unique().tolist()
# Duplicate skills
df_dupskills = pd.read_excel('skills/Other Skills.xlsx', sheet_name='Duplicates')
DUP_SKILLS = df_dupskills.set_index('Skill').to_dict()['Parent']
SKILLS.extend(list(DUP_SKILLS.keys()))

# %%
query = """
select Job_ID, Job_Title, Company, Country, Date_Posted, Description, Keywords_Present, Title_Keywords 
from {}
where Date_Posted > '2020-04-01'
and Description != 'No Description'
and lower(Job_Title) like '%%manager%%'
"""

def extract_df(job):
    df = pd.read_sql(query.format(job), engine)
    df.drop_duplicates(inplace=True)
    no_skill = df['Keywords_Present'].isna()
    df['Num_Skill'] = 0
    df.loc[~no_skill, 'Num_Skill'] = df.loc[~no_skill, 'Keywords_Present'].apply(lambda x: len(x.split(',')))
    print('Number of rows', len(df))
    return df

def extract_skills_all(df):
    i = 0
    job_info_list = []
    initial = dt.now()
    interval = dt.now()
    print_every = int(len(df) / 20)
    for _, job in df.iterrows():
        i += 1
        if i % print_every == 0:
            print("{} jobs processed. Time taken: {}".format(i, dt.now() - interval))
            interval = dt.now()
        all_info = job['Job_Title'] + ' ' + job['Description']
        all_skills = extract_skills(all_info, SKILLS)
        keep_skills, _ = extract_ignore(all_skills, RED_SKILLS, DUP_SKILLS)
        keep_skills.sort()
        # ignore_skills.sort()
        job_info_list.append({
            'job_id': job['Job_ID'],
            'title': job['Job_Title'],
            'company': job['Company'],
            'country': job['Country'],
            'date_posted': job['Date_Posted'],
            'description': job['Description'],
            'indeed_skills': job['Keywords_Present'],
            'skills': keep_skills,
        })
    print("Total time taken: {}".format(dt.now() - initial))
    return pd.DataFrame.from_dict(job_info_list)

# %%
engine = create_engine(secrets['indeed_db'])
df_ds = extract_df('Data_Scientist')
df_ds.head()
# Out:
# Number of rows 260
#               Job_ID                                          Job_Title  \
# 16  b8259e44f8dc12ad  Principal Data Scientist Manager - Cloud Hardw...
# 21  e8565fa183b873d5                    Arity-Data Scientist-Sr Manager
# 25  21df6fd71777d30d        Project Manager - Data Science | Chicago IL
# 31  6560a73b8f1fee47  Corporate Communication Manager - Artificial I...
# 40  92fc3ac15f8c1c81     Project Manager (Data Science & Public Health)
#
#       Company Country Date_Posted  \
# 16  Microsoft     USA  2020-05-02
# 21   Allstate     USA  2020-04-10
# 25     Photon     USA  2020-04-28
# 31   TuSimple     USA  2020-05-11
# 40        ICF     USA  2020-04-29
#
#                                           Description  \
# 16  To delight our customers in a Cloud First worl...
# 21  Founded by The Allstate Corporation in 2016, A...
# 25  Project Manager - Data Science | Chicago IL - ...
# 31  This role is located in San Diego, CA. Relocat...
# 40  ICF seeks a Project Manager with a data scienc...
#
#                        Keywords_Present Title_Keywords  Num_Skill
# 16                             'C', 'R'           None          2
# 21                    'C', 'Excel', 'R'           'Sr'          3
# 25                      'C', 'R', 'SQL'           None          3
# 31  'Artificial Intelligence', 'C', 'R'           None          3
# 40                    'C', 'Excel', 'R'           None          3

# %%
df_da = extract_df('Data_Analyst')
df_da.head()
# Out:
# Number of rows 696
#              Job_ID                                      Job_Title  \
# 2  c406ae5189abe01b          Business Monitoring Analyst / Manager
# 5  653ee53c6262cb44                   Assistant Investment Manager
# 7  4c2ca84fd914a953  Financial Analyst/Assistant Manager - Finance
# 8  ed45e3c6b4603630                             Accounting Manager
# 9  1e71c925b0a6415c             Product Manager (Internal Product)
#
#                          Company    Country Date_Posted  \
# 2                       Wirecard   Malaysia  2020-05-05
# 5  BW INDUSTRIAL DEVELOPMENT JSC    Vietnam  2020-04-10
# 7       In.Corp Global Pte. Ltd.  Singapore  2020-05-04
# 8                   Span systems   Thailand  2020-04-10
# 9                 NVG Technology    Vietnam  2020-04-10
#
#                                          Description   Keywords_Present  \
# 2  The role sits in Business Monitoring function ...  'C', 'Excel', 'R'
# 5  Làm việc tại: Hồ Chí Minh Mức lương: Cạnh Tran...  'C', 'Excel', 'R'
# 7  Duties and responsibilities· Experienced in gr...  'C', 'Excel', 'R'
# 8  Role & ResponsibilitiesManage the financial & ...                'R'
# 9  job descriptionDefine and further develop inte...  'C', 'Excel', 'R'
#
#   Title_Keywords  Num_Skill
# 2           None          3
# 5           None          3
# 7           None          3
# 8           None          1
# 9       'Intern'          3

# %%
df_de = extract_df('Data_Engineer')
df_de.head()
# Out:
# Number of rows 2690
#              Job_ID                                          Job_Title  \
# 0  4d081f53e4763438                 PROJECT MANAGER / PROJECT ENGINEER
# 1  499250d99acee1c0  MANUFACTURING / PRODUCTION - SENIOR ENGINEER /...
# 3  879f1027dbe4d926               Technical Manager_Gelang Patah_18644
# 5  6a3d3ff8e77a86ce                         Product Manager (Payments)
# 8  0904424ee04fb55b               Corporate Planning Manager/ Planners
#
#                 Company   Country Date_Posted  \
# 0  Misi Setia Oil & Gas  Malaysia  2020-04-10
# 1          APM Malaysia  Malaysia  2020-04-10
# 3         Godzilink.com  Malaysia  2020-04-10
# 5    Fave Group Pte Ltd  Malaysia  2020-04-10
# 8              Fircroft  Malaysia  2020-04-25
#
#                                          Description   Keywords_Present  \
# 0  Location:BalakongResponsibilities:Define proje...           'C', 'R'
# 1  APM Automotive Holdings Berhad, is one of the ...          'Go', 'R'
# 3  1. 协助项目经理或项目总工进行项目图纸与设计管理工作Assist Project Mana...           'C', 'R'
# 5  Fave is the next generation Digital Merchant P...  'C', 'Excel', 'R'
# 8  The Role:Location: Kuala Lumpur, MalaysiaTenur...           'C', 'R'
#
#   Title_Keywords  Num_Skill
# 0           None          2
# 1           None          2
# 3           None          2
# 5           None          3
# 8           None          2

# %%
df_mle = extract_df('Machine_Learning_Engineer')
df_mle.head()
# Out:
# Number of rows 440
#               Job_ID                                      Job_Title  \
# 2   b9946084c93f3877                               Engineer Manager
# 3   8caaff8a4e42e3de                         Data Scientist Manager
# 5   0aae98815a6a20a4                                Program Manager
# 12  69edc117a66b2bb7                         Senior Product Manager
# 14  0196cb5a9fee96b4  APJC Competitive Business Development Manager
#
#                                               Company    Country Date_Posted  \
# 2                                            Siam M&M   Thailand  2020-04-10
# 3   Pasona HR Consulting Recruitment (Thailand) Co...   Thailand  2020-04-10
# 5                                     Program Manager  Indonesia  2020-04-10
# 12                                            Singtel  Singapore  2020-05-11
# 14                      CISCO SYSTEMS (USA) PTE. LTD.  Singapore  2020-04-24
#
#                                           Description  \
# 2   Job DescriptionResponsibilities:Handle for Eng...
# 3   Job ID 12563Occupation Data Scientist ManagerB...
# 5   Wavemaker Partners is Southeast Asia’s leading...
# 12  DataSpark was created from a vision to transfo...
# 14  Roles & ResponsibilitiesWhat You'll doAs Compe...
#
#                 Keywords_Present Title_Keywords  Num_Skill
# 2                 'C', 'Go', 'R'           None          3
# 3                       'C', 'R'           None          2
# 5              'C', 'Excel', 'R'           None          3
# 12             'C', 'Excel', 'R'       'Senior'          3
# 14  'C', 'Machine Learning', 'R'           None          3

# %%
engine.dispose()
df_dsj = extract_skills_all(df_ds)
df_dsj.head()
# Out:
# 13 jobs processed. Time taken: 0:00:47.412693
# 26 jobs processed. Time taken: 0:00:51.422837
# 39 jobs processed. Time taken: 0:00:34.137897
# 52 jobs processed. Time taken: 0:00:41.589995
# 65 jobs processed. Time taken: 0:00:46.706060
# 78 jobs processed. Time taken: 0:00:43.167474
# 91 jobs processed. Time taken: 0:00:38.465031
# 104 jobs processed. Time taken: 0:00:42.419194
# 117 jobs processed. Time taken: 0:00:29.890351
# 130 jobs processed. Time taken: 0:00:48.374952
# 143 jobs processed. Time taken: 0:00:40.822881
# 156 jobs processed. Time taken: 0:00:52.491858
# 169 jobs processed. Time taken: 0:01:27.793107
# 182 jobs processed. Time taken: 0:00:45.115368
# 195 jobs processed. Time taken: 0:00:40.794447
# 208 jobs processed. Time taken: 0:00:33.862468
# 221 jobs processed. Time taken: 0:00:28.591172
# 234 jobs processed. Time taken: 0:00:38.845923
# 247 jobs processed. Time taken: 0:00:28.568055
# 260 jobs processed. Time taken: 0:00:49.763342
# Total time taken: 0:14:33.551391
#                                                title    company country  \
# 0  Principal Data Scientist Manager - Cloud Hardw...  Microsoft     USA
# 1                    Arity-Data Scientist-Sr Manager   Allstate     USA
# 2        Project Manager - Data Science | Chicago IL     Photon     USA
# 3  Corporate Communication Manager - Artificial I...   TuSimple     USA
# 4     Project Manager (Data Science & Public Health)        ICF     USA
#
#   date_posted                                        description  \
# 0  2020-05-02  To delight our customers in a Cloud First worl...
# 1  2020-04-10  Founded by The Allstate Corporation in 2016, A...
# 2  2020-04-28  Project Manager - Data Science | Chicago IL - ...
# 3  2020-05-11  This role is located in San Diego, CA. Relocat...
# 4  2020-04-29  ICF seeks a Project Manager with a data scienc...
#
#                          indeed_skills  \
# 0                             'C', 'R'
# 1                    'C', 'Excel', 'R'
# 2                      'C', 'R', 'SQL'
# 3  'Artificial Intelligence', 'C', 'R'
# 4                    'C', 'Excel', 'R'
#
#                                               skills
# 0  [Applied Statistics, Automation, Cloud Service...
# 1  [Agile, Architecture, Business Analysis, Busin...
# 2  [Apache Spark, Business Intelligence (BI), Dat...
# 3  [Algorithm, Array, Artificial Intelligence (AI...
# 4  [Analytical, Business Analysis, Collaboration,...

# %%
df_daj = extract_skills_all(df_da)
df_daj.head()
# Out:
# 34 jobs processed. Time taken: 0:01:20.820214
# 68 jobs processed. Time taken: 0:01:37.464968
# 102 jobs processed. Time taken: 0:01:43.006114
# 136 jobs processed. Time taken: 0:02:03.294674
# 170 jobs processed. Time taken: 0:01:47.042629
# 204 jobs processed. Time taken: 0:01:56.214504
# 238 jobs processed. Time taken: 0:02:00.264164
# 272 jobs processed. Time taken: 0:01:38.296331
# 306 jobs processed. Time taken: 0:01:22.984659
# 340 jobs processed. Time taken: 0:01:50.277857
# 374 jobs processed. Time taken: 0:01:47.676128
# 408 jobs processed. Time taken: 0:02:02.348663
# 442 jobs processed. Time taken: 0:01:56.399032
# 476 jobs processed. Time taken: 0:01:16.338490
# 510 jobs processed. Time taken: 0:01:28.163783
# 544 jobs processed. Time taken: 0:01:28.396423
# 578 jobs processed. Time taken: 0:01:32.174170
# 612 jobs processed. Time taken: 0:01:44.265618
# 646 jobs processed. Time taken: 0:01:21.433254
# 680 jobs processed. Time taken: 0:01:24.078403
# Total time taken: 0:34:03.115963
#                                            title  \
# 0          Business Monitoring Analyst / Manager
# 1                   Assistant Investment Manager
# 2  Financial Analyst/Assistant Manager - Finance
# 3                             Accounting Manager
# 4             Product Manager (Internal Product)
#
#                          company    country date_posted  \
# 0                       Wirecard   Malaysia  2020-05-05
# 1  BW INDUSTRIAL DEVELOPMENT JSC    Vietnam  2020-04-10
# 2       In.Corp Global Pte. Ltd.  Singapore  2020-05-04
# 3                   Span systems   Thailand  2020-04-10
# 4                 NVG Technology    Vietnam  2020-04-10
#
#                                          description      indeed_skills  \
# 0  The role sits in Business Monitoring function ...  'C', 'Excel', 'R'
# 1  Làm việc tại: Hồ Chí Minh Mức lương: Cạnh Tran...  'C', 'Excel', 'R'
# 2  Duties and responsibilities· Experienced in gr...  'C', 'Excel', 'R'
# 3  Role & ResponsibilitiesManage the financial & ...                'R'
# 4  job descriptionDefine and further develop inte...  'C', 'Excel', 'R'
#
#                                               skills
# 0  [Automation, Brand Management, Credit Risk, Da...
# 1  [Accuracy, Analysis, Analytical, Annual Report...
# 2  [Analytical, Analytical Thinking, Audit, Budge...
# 3  [Accounting, Analytical, Budget, Finance, Fore...
# 4  [Administration, Agile, Analytical Thinking, A...

# %%
df_dej = extract_skills_all(df_de)
df_dej.head()
# Out:
# 134 jobs processed. Time taken: 0:04:17.496911
# 268 jobs processed. Time taken: 0:07:59.705177
# 402 jobs processed. Time taken: 0:09:11.208289
# 536 jobs processed. Time taken: 0:09:50.369051
# 670 jobs processed. Time taken: 0:09:19.447551
# 804 jobs processed. Time taken: 0:09:34.888542
# 938 jobs processed. Time taken: 0:09:14.067171
# 1072 jobs processed. Time taken: 0:09:17.812506
# 1206 jobs processed. Time taken: 0:08:38.646464
# 1340 jobs processed. Time taken: 0:10:26.397910
# 1474 jobs processed. Time taken: 0:09:07.829619
# 1608 jobs processed. Time taken: 0:08:29.045128
# 1742 jobs processed. Time taken: 0:09:37.203054
# 1876 jobs processed. Time taken: 0:10:05.764167
# 2010 jobs processed. Time taken: 0:10:21.065463
# 2144 jobs processed. Time taken: 0:09:29.141505
# 2278 jobs processed. Time taken: 0:09:20.831176
# 2412 jobs processed. Time taken: 0:09:17.313930
# 2546 jobs processed. Time taken: 0:06:02.922331
# 2680 jobs processed. Time taken: 0:06:05.263118
# Total time taken: 2:56:12.466360
#                                                title               company  \
# 0                 PROJECT MANAGER / PROJECT ENGINEER  Misi Setia Oil & Gas
# 1  MANUFACTURING / PRODUCTION - SENIOR ENGINEER /...          APM Malaysia
# 2               Technical Manager_Gelang Patah_18644         Godzilink.com
# 3                         Product Manager (Payments)    Fave Group Pte Ltd
# 4               Corporate Planning Manager/ Planners              Fircroft
#
#     country date_posted                                        description  \
# 0  Malaysia  2020-04-10  Location:BalakongResponsibilities:Define proje...
# 1  Malaysia  2020-04-10  APM Automotive Holdings Berhad, is one of the ...
# 2  Malaysia  2020-04-10  1. 协助项目经理或项目总工进行项目图纸与设计管理工作Assist Project Mana...
# 3  Malaysia  2020-04-10  Fave is the next generation Digital Merchant P...
# 4  Malaysia  2020-04-25  The Role:Location: Kuala Lumpur, MalaysiaTenur...
#
#        indeed_skills                                             skills
# 0           'C', 'R'  [Administration, Change Management, Chart, Con...
# 1          'Go', 'R'  [Automotive, Design, Documentation, Email, Hum...
# 2           'C', 'R'  [Brand Management, Civil Engineering, Communic...
# 3  'C', 'Excel', 'R'  [Application Programming Interface (API), Coll...
# 4           'C', 'R'  [Audit, Business Intelligence (BI), Business P...

# %%
df_mlej = extract_skills_all(df_mle)
df_mlej.head()
# Out:
# 22 jobs processed. Time taken: 0:01:05.948893
# 44 jobs processed. Time taken: 0:01:26.009153
# 66 jobs processed. Time taken: 0:01:25.844878
# 88 jobs processed. Time taken: 0:01:20.957422
# 110 jobs processed. Time taken: 0:01:22.718905
# 132 jobs processed. Time taken: 0:01:18.102775
# 154 jobs processed. Time taken: 0:01:12.583946
# 176 jobs processed. Time taken: 0:01:28.683881
# 198 jobs processed. Time taken: 0:01:24.298506
# 220 jobs processed. Time taken: 0:01:09.703242
# 242 jobs processed. Time taken: 0:01:09.360919
# 264 jobs processed. Time taken: 0:01:25.874231
# 286 jobs processed. Time taken: 0:01:14.530301
# 308 jobs processed. Time taken: 0:01:28.812989
# 330 jobs processed. Time taken: 0:01:36.846727
# 352 jobs processed. Time taken: 0:01:23.724539
# 374 jobs processed. Time taken: 0:01:22.534612
# 396 jobs processed. Time taken: 0:01:20.730154
# 418 jobs processed. Time taken: 0:01:05.178908
# 440 jobs processed. Time taken: 0:01:26.059972
# Total time taken: 0:26:51.031079
#                                            title  \
# 0                               Engineer Manager
# 1                         Data Scientist Manager
# 2                                Program Manager
# 3                         Senior Product Manager
# 4  APJC Competitive Business Development Manager
#
#                                              company    country date_posted  \
# 0                                           Siam M&M   Thailand  2020-04-10
# 1  Pasona HR Consulting Recruitment (Thailand) Co...   Thailand  2020-04-10
# 2                                    Program Manager  Indonesia  2020-04-10
# 3                                            Singtel  Singapore  2020-05-11
# 4                      CISCO SYSTEMS (USA) PTE. LTD.  Singapore  2020-04-24
#
#                                          description  \
# 0  Job DescriptionResponsibilities:Handle for Eng...
# 1  Job ID 12563Occupation Data Scientist ManagerB...
# 2  Wavemaker Partners is Southeast Asia’s leading...
# 3  DataSpark was created from a vision to transfo...
# 4  Roles & ResponsibilitiesWhat You'll doAs Compe...
#
#                   indeed_skills  \
# 0                'C', 'Go', 'R'
# 1                      'C', 'R'
# 2             'C', 'Excel', 'R'
# 3             'C', 'Excel', 'R'
# 4  'C', 'Machine Learning', 'R'
#
#                                               skills
# 0  [Analytical Thinking, Budget, Communication, D...
# 1  [Analysis, Business Acumen, Business Administr...
# 2  [Advertising, Agile, Artificial Intelligence (...
# 3  [Agile, Analytical Thinking, Business Analysis...
# 4  [Architectural Engineering, Architecture, Arti...

# %%
def get_skill_count(df, d):
    for _, row in df.iterrows():
        for s in row['skills']:
            if s in d:
                d[s] += 1
            else:
                d[s] = 1

# %%
skill_count = {}

get_skill_count(df_dsj, skill_count)
get_skill_count(df_daj, skill_count)
get_skill_count(df_dej, skill_count)
get_skill_count(df_mlej, skill_count)

# %%
skill_count = {k: v for k, v in sorted(skill_count.items(), key=lambda item: item[1], reverse=True)}
skill_count
# Out:
# {'Design': 1488,
#  'Leadership': 1472,
#  'Communication': 1433,
#  'Training': 1313,
#  'Project Management': 1168,
#  'Analytical': 1159,
#  'Engineering': 1116,
#  'Market': 1013,
#  'Budget': 966,
#  'Platform': 887,
#  'Reporting': 841,
#  'Sales': 836,
#  'Innovation': 834,
#  'Management': 832,
#  'Collaboration': 821,
#  'Problem Solving': 798,
#  'Presentation': 759,
#  'Computer Science': 731,
#  'Analysis': 710,
#  'Documentation': 692,
#  'TestNG': 662,
#  'Law': 643,
#  'Security': 628,
#  'Research': 610,
#  'Testing': 579,
#  'Information Technology (IT)': 575,
#  'Construction': 568,
#  'Microsoft Excel': 558,
#  'Marketing': 556,
#  'Microsoft Access': 555,
#  'Machine Learning': 543,
#  'Product Management': 536,
#  'Written Communication': 529,
#  'Network': 516,
#  'Administration': 496,
#  'Agile': 492,
#  'Writing': 487,
#  'Audit': 486,
#  'Decision Making': 480,
#  'Architecture': 479,
#  'Manufacturing': 459,
#  'Insurance': 443,
#  'Brand Management': 441,
#  'Customer Service': 418,
#  'English': 415,
#  'Finance': 413,
#  'Product Development': 391,
#  'Scheduling': 390,
#  'Business Development': 368,
#  'Negotiation': 363,
#  'Ad Design': 362,
#  'Email': 360,
#  'Business Analysis': 351,
#  'Processing': 350,
#  'Automation': 344,
#  'Electronics': 341,
#  'Artificial Intelligence (AI)': 339,
#  'Interpreter': 333,
#  'Division': 332,
#  'Nonverbal Communication': 328,
#  'Hardware': 319,
#  'Data Analysis': 317,
#  'Consulting': 315,
#  'Golang': 310,
#  'Teamwork': 307,
#  'Organizational Skill': 307,
#  'Database': 305,
#  'Quality Assurance (QA)': 303,
#  'Creatio': 302,
#  'Coaching': 295,
#  'Human Resource (HR)': 293,
#  'Recruiting': 292,
#  'Investment': 290,
#  'Microsoft Office': 289,
#  'Customer Experience': 284,
#  'Healthcare': 283,
#  'Accuracy': 280,
#  'Accounting': 280,
#  'Trade': 279,
#  'Data Science': 272,
#  'Microsoft PowerPoint': 272,
#  'Software Engineering': 259,
#  'Selection': 259,
#  'Play': 247,
#  'Business Process': 240,
#  'User Experience (UX)': 234,
#  'Data Analytics': 230,
#  'History': 227,
#  'Subject Matter Expert (SME)': 224,
#  'Product Roadmap': 224,
#  'Transformer': 222,
#  'IT Operations': 222,
#  'Transportation': 217,
#  'Networking': 216,
#  'C': 214,
#  'Logistics': 213,
#  'Change Management': 210,
#  'Time Management': 208,
#  'Quality Control': 207,
#  'Risk Management': 205,
#  'Procurement': 194,
#  'Creativity': 192,
#  'Scrum': 191,
#  'Forecasting': 188,
#  'Data Management': 188,
#  'Microsoft': 187,
#  'Economics': 180,
#  'Statistics': 178,
#  'Lean Software Development': 173,
#  'Complexity': 172,
#  'Civil Engineering': 170,
#  'Oral Communication': 169,
#  'Modelling': 169,
#  'Urban Engineering': 169,
#  'Internet': 167,
#  'Mathematics': 166,
#  'Table': 165,
#  'Methodology': 164,
#  'Privacy': 162,
#  'R': 159,
#  'Software Development': 158,
#  'Technical Support': 156,
#  'Product Marketing': 155,
#  'Closing': 154,
#  'Repair': 154,
#  'Saving': 153,
#  'Strategic Planning': 150,
#  'LeSS': 150,
#  'eCommerce': 150,
#  'Microsoft Outlook': 150,
#  'Business Intelligence (BI)': 149,
#  'Retail': 149,
#  'Video': 148,
#  'Classification': 148,
#  'Operating System': 148,
#  'Mechanical Engineering': 147,
#  'Customer Relationship Management (CRM)': 146,
#  'Property': 145,
#  'Programming': 143,
#  'Quality Management': 143,
#  'Research and Development (R&D)': 141,
#  'Information System': 140,
#  'Configuration': 140,
#  'Media': 139,
#  'Effective Communication': 139,
#  'Medium': 138,
#  'Performance Management': 138,
#  'Big Data': 137,
#  'Ethics': 137,
#  'Windows': 134,
#  'Business Acumen': 133,
#  'Structured Query Language (SQL)': 130,
#  'Systems Engineering': 130,
#  'Objective-C': 129,
#  'Electrical Engineering': 129,
#  'Business Plan': 128,
#  'Rally': 127,
#  'Electronic Engineering': 127,
#  'Translation': 127,
#  'Recommendations AI': 126,
#  'Client Relations': 124,
#  'Critical Thinking': 123,
#  'Dashboard': 120,
#  'Team Building': 120,
#  'Business Administration': 119,
#  'Twitter': 117,
#  'Software Tool': 117,
#  'Automotive': 117,
#  'Business Strategy': 116,
#  'Chemical': 116,
#  'SAP': 115,
#  'Algorithm': 113,
#  'Sentry': 113,
#  'Banking': 112,
#  'Utility': 112,
#  'Visualization': 111,
#  'Financial Services': 111,
#  'Cybersecurity': 111,
#  'Facebook': 106,
#  'Software as a Service (SaaS)': 106,
#  'Project Planning': 105,
#  'Protocol': 105,
#  'Asset Management': 104,
#  'Searching': 104,
#  'Agile Software Development': 103,
#  'Gradle': 102,
#  'User Interface (UI)': 101,
#  'AutoCAD': 101,
#  'Amazon S3': 100,
#  'Computer Engineering': 100,
#  'News': 99,
#  'Market Research': 99,
#  'Development Tools': 99,
#  'Jira': 96,
#  'Business Management': 96,
#  'Assembly': 96,
#  'Root Cause Analysis': 96,
#  'Marketing Research': 94,
#  'Software Development Life Cycle (SDLC)': 93,
#  'Advertising': 92,
#  'Enterprise Software': 91,
#  'Mapping': 90,
#  'Coding': 90,
#  'Salesforce': 89,
#  'Sports': 88,
#  'Business Operations': 87,
#  'Cloud Service': 86,
#  'Entertainment': 86,
#  'Computing': 85,
#  'Equity': 85,
#  'Enterprise Resource Planning (ERP)': 83,
#  'Amazon Web Service (AWS)': 83,
#  'Reinforcement Learning': 83,
#  'Software Application': 83,
#  'Sustainability': 82,
#  'Vmware': 82,
#  'Variable': 81,
#  '.NET Framework': 81,
#  'Box': 81,
#  'Telecommunication': 80,
#  'Cloud Computing': 80,
#  'Empathy': 80,
#  'Control System': 80,
#  'Distributed System': 79,
#  'Python': 79,
#  'Calendar': 79,
#  'Social Media': 78,
#  'Chart': 78,
#  'Performance Review': 78,
#  'Software System': 77,
#  'Microsoft Azure': 76,
#  'Operations Management': 76,
#  'Competition': 75,
#  'Template': 75,
#  'Aerospace': 74,
#  'LinkedIn': 74,
#  'Instrumentation': 73,
#  'Architectural Engineering': 73,
#  'Workday': 73,
#  'Network Security': 71,
#  'Manufacturing Engineering': 71,
#  'Chemistry': 70,
#  'Perceptron': 70,
#  'Production Process': 69,
#  'Real Estate': 69,
#  'Peripheral': 69,
#  'Semiconductors': 67,
#  'Data Visualization': 66,
#  'Business Model': 66,
#  'Engineering Technology': 66,
#  'Sales Operations': 66,
#  'Indonesian': 65,
#  'Information Security': 65,
#  'Quality Engineering': 65,
#  'Population': 64,
#  'DevOps': 64,
#  'Resource Management': 63,
#  'Industrial Engineering': 63,
#  'Machinery': 63,
#  'Array': 62,
#  'Life Science': 62,
#  'Service Management': 62,
#  'Dataset': 62,
#  'Programming Language': 62,
#  'Philosophy': 62,
#  'Microsoft Word': 61,
#  'Imagine': 60,
#  'Poster': 60,
#  'Social Work': 59,
#  'Construction Engineering': 59,
#  'Oracle': 58,
#  'Metals': 58,
#  'Financial Management': 58,
#  'Apache Spark': 57,
#  'Data Mining': 57,
#  'Reasoning': 57,
#  'Firewall': 57,
#  'Employee Development': 57,
#  'Prototyping': 56,
#  'React': 56,
#  'Clear Communication': 55,
#  'Application Programming Interface (API)': 55,
#  'Hospitality': 55,
#  'Requirements Gathering': 54,
#  'Big Data Analysis': 54,
#  'Logic': 54,
#  'Process Engineering': 54,
#  'UX Design': 54,
#  'Data Modelling': 53,
#  'Statistical Analysis': 53,
#  'Digital Marketing': 53,
#  'Physics': 53,
#  'Wireframes': 53,
#  'Information Threat': 52,
#  'Technical Writing': 52,
#  'Property Management Software': 52,
#  'Internet of Things (IoT)': 51,
#  'Virtualization': 51,
#  'Web Design': 51,
#  'Product Knowledge': 51,
#  'Data Engineering': 50,
#  'Compiler': 50,
#  'Geology': 49,
#  'Confluence': 48,
#  'Big Data Analytics': 48,
#  'Code Review': 48,
#  'Image': 48,
#  'A/B Testing': 48,
#  'Delegation': 48,
#  'Mining': 48,
#  'Robotics': 47,
#  'Java': 47,
#  'Deep Learning': 46,
#  'Configuration Management': 46,
#  'Adaptability': 46,
#  'Blogging': 46,
#  'Fabrication': 46,
#  'Biology': 45,
#  'Risk Analysis': 44,
#  'Velocity': 44,
#  'Management Information System (MIS)': 44,
#  'Incident Management': 43,
#  'Business Ethics': 43,
#  'Intellectual Property (IP)': 43,
#  'Chemical Engineering': 43,
#  'Japanese': 43,
#  'Kanban': 43,
#  'Sales Presentation': 43,
#  'Optics': 43,
#  'Forth': 42,
#  'Statistical Model': 42,
#  'Wage': 42,
#  'Analytical Thinking': 42,
#  'Front End': 42,
#  'Router': 42,
#  'Usability Engineering': 42,
#  'Microsoft Power BI': 41,
#  'Software Design': 41,
#  'Vietnamese': 41,
#  'Management Consulting': 41,
#  'Internet Protocol (IP)': 41,
#  'Financial Statement': 41,
#  'Information Management': 41,
#  'Aviation': 41,
#  'jQuery': 40,
#  'Computer Vision': 40,
#  'German': 40,
#  'Public Relations (PR)': 40,
#  'Market Analysis': 40,
#  'Geotechnical Engineering': 40,
#  'Medicine': 39,
#  'Manufacturing Operations': 39,
#  'Cloud Technology': 38,
#  'Contact Manager': 38,
#  'Web Application Development': 38,
#  'Pragmatics': 38,
#  'Business Analytics': 37,
#  'Cloud Platform': 37,
#  'Data Security': 37,
#  'Data Structure': 37,
#  'Brainstorming': 37,
#  'Nice': 37,
#  'Social Security': 37,
#  'Arithmetic': 37,
#  'System Analysis': 37,
#  'Microsoft Publisher': 36,
#  'Web Application': 36,
#  'Tableau': 36,
#  'Vulnerability': 36,
#  'Differentiation': 36,
#  'ISO 9001': 36,
#  'Streaming': 35,
#  'Publishing': 35,
#  'Regression': 35,
#  'UI Design': 35,
#  'Data Gathering': 35,
#  'Continuous Integration (CI)': 35,
#  'Environmental Engineering': 35,
#  'Digital Media': 34,
#  'Uncertainty': 34,
#  'Inside Sales': 34,
#  'Audio': 34,
#  'Rehabilitation': 34,
#  'Requirement Analysis': 34,
#  'Google Analytics': 34,
#  'Supply Chain Management': 34,
#  'Agile Methodology': 34,
#  'Supply Chain Risk Management': 34,
#  'Links': 33,
#  'Radio': 33,
#  'Android': 33,
#  'Art History': 32,
#  'Environmental Science': 32,
#  'Benchmarking': 32,
#  'Technical Documentation': 32,
#  'Outreach': 31,
#  'Systems Management': 31,
#  'Software Architecture': 31,
#  'System Administration': 31,
#  'Natural Language Processing (NLP)': 30,
#  'Product Lifecycle Management (PLM)': 30,
#  'Business Intelligence Tool': 30,
#  'Source Control': 30,
#  'Support Engineering': 30,
#  'Financial Modelling': 30,
#  'Linux': 30,
#  'Instagram': 29,
#  'Predictive Analytics': 29,
#  'Leadership Development': 29,
#  'Psychology': 29,
#  'iOS': 29,
#  'Fraction': 29,
#  'Hydrology': 29,
#  'Public Health': 28,
#  'Storytelling': 28,
#  'Sales Management': 28,
#  'Software Development Kit (SDK)': 28,
#  'Construction Law': 28,
#  'Graph': 27,
#  'Conflict Management': 27,
#  'Data Acquisition': 27,
#  'Continuous Delivery (CD)': 27,
#  'International Trade': 27,
#  'Music': 27,
#  'Agriculture': 27,
#  'Data Architecture': 27,
#  'Account Receivable': 27,
#  'C++': 27,
#  'Task Management': 26,
#  'Branding': 26,
#  'Software Package': 26,
#  'Statistical Modelling': 26,
#  'Virtual Reality (VR)': 26,
#  'Ergonomics': 26,
#  'Commodity': 26,
#  'Spanish': 26,
#  'Operations Research': 26,
#  'Network Architecture': 26,
#  'Scripting': 25,
#  'Budget Planning': 25,
#  'Newsletters': 25,
#  'Private Equity': 25,
#  'RStudio': 24,
#  'Literature': 24,
#  'Azure Machine Learning': 24,
#  'Biotechnology': 24,
#  'Data Reporting': 24,
#  'Editing': 24,
#  'Balance Sheet': 24,
#  'Sequence': 24,
#  'Calculus': 24,
#  'Accounts Payable': 24,
#  'Access Control': 24,
#  'Mechanics': 24,
#  'Autonomous Vehicle': 23,
#  'Predictive Model': 23,
#  'Data Presentation': 23,
#  'Sampling': 23,
#  'Extract Transform Load (ETL)': 23,
#  'Online Marketing': 23,
#  'Human Resource Management': 23,
#  'Photography': 23,
#  'Knowledge Management': 23,
#  'Process Model': 23,
#  'Data Privacy': 23,
#  'Investment Banking': 23,
#  'Tracking System': 23,
#  'QA Testing': 23,
#  'Patient Care': 23,
#  'Structural Engineering': 23,
#  'Thermodynamics': 23,
#  'Machining': 23,
#  'SAS': 22,
#  'Youtube': 22,
#  'Informatics': 22,
#  'Active Listening': 22,
#  'Content Management System (CMS)': 22,
#  'Lead Generation': 22,
#  'Pharmacy': 22,
#  'Welding': 22,
#  'Processor': 22,
#  'Fluid Mechanics': 22,
#  'Data Pipeline': 21,
#  'Oil and Gas': 21,
#  'NP Completeness': 21,
#  'Korean': 21,
#  'Plastics': 21,
#  'Report Analysis': 21,
#  'Epic': 21,
#  'Earned Value Management (EVM)': 21,
#  'Facilities Engineering': 21,
#  'Physical Science': 21,
#  'Electrical Socket': 21,
#  'Network Management': 20,
#  'Sales Leadership': 20,
#  'Outsourcing': 20,
#  'Arts': 20,
#  'Web Development': 20,
#  'Relational Database': 20,
#  'Brave': 20,
#  'Talent Management': 20,
#  'Target Audience': 20,
#  'User Experience Design': 20,
#  'Debugging': 20,
#  'Application Security': 20,
#  'Probability': 20,
#  'Software Stack': 20,
#  'Property Management': 20,
#  'Reliability Engineering': 20,
#  'Oncology': 19,
#  'Therapy': 19,
#  'JavaScript': 19,
#  'Production Set': 19,
#  'Database Administration': 19,
#  'Airlines': 19,
#  'Meteorology': 19,
#  'Metrology': 19,
#  'Certified Information Systems Security Professional (CISSP)': 19,
#  'Shell': 19,
#  'Bond': 19,
#  'Cognitive': 19,
#  'Cookies': 19,
#  'Unix': 19,
#  'Public Speaking': 19,
#  'Real Property': 19,
#  'Underwriting': 18,
#  'Computing Platform': 18,
#  'Quantitative Research': 18,
#  'Persuasion': 18,
#  'Augmented Reality (AR)': 18,
#  'Facebook Ads': 18,
#  'Design Analysis': 18,
#  'Scorecard': 18,
#  'Recreation': 18,
#  'Web Analytics': 18,
#  'Computer Worm': 18,
#  'Energy Consumption': 18,
#  'Capital Budgeting': 18,
#  'Enterprise System': 17,
#  'Annual Report': 17,
#  'Correlation': 17,
#  'Digital Art': 17,
#  'Shopify': 17,
#  'Scheme': 17,
#  'Rapid Application Development': 17,
#  'Securities': 17,
#  'Value Stream Mapping': 17,
#  'Product Testing': 17,
#  'Free Hand': 17,
#  'Cost Accounting': 17,
#  'Node.js': 17,
#  'Data Science Tool': 16,
#  'Journalism': 16,
#  'Machine Learning Algorithm': 16,
#  'Materials Science': 16,
#  'eCommerce Platforms': 16,
#  'Autoregressive (AR) Model': 16,
#  'Spring': 16,
#  'Neural Network': 16,
#  'VOIP': 16,
#  'Sports Engineering': 16,
#  'Development Management': 16,
#  'Crisis Management': 16,
#  'Inference': 16,
#  'Generally Accepeted Accounting Principles (GAAP)': 16,
#  'Variance Analysis': 16,
#  'Public Administration': 16,
#  'Business Writing': 16,
#  'Sketch': 16,
#  'Environmental Planning': 16,
#  'ISO 13485': 16,
#  'Environmental Consulting': 16,
#  'Rendering': 16,
#  'Content Management': 15,
#  'Revenue Recognition': 15,
#  'Business Economics': 15,
#  'Google Ads': 15,
#  'Nutrition': 15,
#  'Microsoft SQL Server': 15,
#  'Microsoft SQL Servers': 15,
#  'Management Accounting': 15,
#  'Content Strategy': 15,
#  'Algebra': 15,
#  'Information and Communications Technology (ICT)': 15,
#  'Cold Calling': 15,
#  'CVS': 15,
#  'Technology Management': 15,
#  'Business Continuity Planning': 15,
#  'Blockchain': 15,
#  'Product Liability': 15,
#  'Advertising Management': 15,
#  'Public Policy': 14,
#  'Television': 14,
#  'Signal Processing': 14,
#  'Time Series': 14,
#  'Emotional Intelligence (EQ)': 14,
#  'Clustering': 14,
#  'Foreign Language': 14,
#  'Swift': 14,
#  'Economic Development': 14,
#  'Cisco Certified Network Associate (CCNA)': 14,
#  'Problem Management': 14,
#  'Geometry': 14,
#  'Project Chart': 14,
#  'Materials Management': 14,
#  'Environmental Law': 14,
#  'Venture Capital (VC)': 13,
#  'Urban Planning': 13,
#  'Apparel': 13,
#  'Pivot Table': 13,
#  'Google Workspace': 13,
#  'Database System': 13,
#  'Investment Management': 13,
#  'Ruby on Rails': 13,
#  'MATLAB': 13,
#  'Social Media Platform': 13,
#  'Currency': 13,
#  'Online Business': 13,
#  'Border Gateway Protocol (BGP)': 13,
#  'Water Engineering': 13,
#  'Landscape Architecture': 13,
#  'Economic Analysis': 13,
#  'Profiling': 13,
#  'Biostatistics': 12,
#  'Venture Capiral': 12,
#  'Financial Market': 12,
#  'Legal Management': 12,
#  'IP Addressing': 12,
#  'Marketing Channel': 12,
#  'UX Research': 12,
#  'Virtual Machine': 12,
#  'Slack': 12,
#  'Database Management System': 12,
#  'Wireless LAN': 12,
#  'Power Management': 12,
#  'Power Systems Engineering': 12,
#  'vSphere': 12,
#  'Storage System': 12,
#  'Domain Name System (DNS)': 12,
#  'Physical Security': 12,
#  'Platform as a Service (PaaS)': 12,
#  'Records Management': 12,
#  'Build Automation': 12,
#  'Verification And Validation': 12,
#  'Applied Statistics': 11,
#  'Robot': 11,
#  'Pharmaceutics': 11,
#  'Pandas': 11,
#  'Cascading Style Sheet (CSS)': 11,
#  'Database Design': 11,
#  'Logistic Regression': 11,
#  'Distributed Computing': 11,
#  'Scripting Language': 11,
#  'Genomics': 11,
#  'Marketing Design': 11,
#  'GUI Design': 11,
#  'French': 11,
#  'Mergers and Acquisitions (M&A)': 11,
#  'Capacity Management': 11,
#  'iland': 11,
#  'Infrastructure as a Service (IaaS)': 11,
#  'Geographic Information System (GIS)': 11,
#  'PL': 11,
#  'Scrum Methodology': 11,
#  'Editor': 11,
#  'Software Testing': 11,
#  'Angular': 11,
#  'Accounting Software': 11,
#  'Computer Hardware': 11,
#  'Authentication': 11,
#  'Materials Engineering': 11,
#  'Tree': 11,
#  'Human-Computer Interaction (HCI)': 11,
#  'Approximation': 11,
#  'Language Learning': 11,
#  'Credit Risk': 10,
#  'Marketing Analytics': 10,
#  'Computer Programming': 10,
#  'macOS': 10,
#  'International Business': 10,
#  'Operational Databases': 10,
#  'Data Cleansing': 10,
#  'Search Engine Optimization (SEO)': 10,
#  'Financial Engineering': 10,
#  'Computing Technology': 10,
#  'Software Requirement': 10,
#  'Databricks': 10,
#  'Cluster Analysis': 10,
#  'Exploit': 10,
#  'Complex Analysis': 10,
#  'Zoom': 10,
#  'C#': 10,
#  'Geography': 10,
#  'Data Transmission': 10,
#  'Supply and Demand': 10,
#  'Middleware': 10,
#  'Security Engineering': 10,
#  'Amazon EC2': 10,
#  'Interior Design': 10,
#  'Data Preparation': 10,
#  'Localization': 10,
#  'Malay': 10,
#  'Unit Cost': 10,
#  'Industrial Automation': 10,
#  'Network Service': 10,
#  'Casting': 10,
#  'ISO 9000': 10,
#  'Kubernetes': 10,
#  'Biomaterials Engineering': 10,
#  'Encryption': 10,
#  'Competitive Strategy': 10,
#  'DynamoDB': 10,
#  'Multi-Factor Authentication': 10,
#  'Corporate Communication': 9,
#  'SAS Statistical Analysis': 9,
#  'Data Capture': 9,
#  'Email Management': 9,
#  'Econometrics': 9,
#  'Natural Language Understanding': 9,
#  'Gantt Chart': 9,
#  'Algorithm Design': 9,
#  'Object-Oriented Design': 9,
#  'Entrepreneurship': 9,
#  'MLFlow': 9,
#  'Needs Analysis': 9,
#  'Biochemistry': 9,
#  'Managerial Finance': 9,
#  'Digital Image': 9,
#  'Content Marketing': 9,
#  'Version Control': 9,
#  'Growth Strategy': 9,
#  'Business Consulting': 9,
#  'Derivative': 9,
#  'Graphic Design': 9,
#  'Financial Risk': 9,
#  'Sorting': 9,
#  'Amazon EMR': 9,
#  'Payment Processing': 9,
#  'CMM': 9,
#  'Unity': 9,
#  'Pharmacodynamics (PD)': 9,
#  'Factoring': 9,
#  'Control Engineering': 9,
#  'Mechatronics': 9,
#  'Neural Engineering': 9,
#  'Rent': 9,
#  'Electromechanics': 9,
#  'Transportation Engineering': 9,
#  'Computer-aided Design': 9,
#  'Query Language': 8,
#  'Scaled Agile Framework (SAFe)': 8,
#  'Malware': 8,
#  'Build Tool': 8,
#  'Decision Tree': 8,
#  'Speech Recognition': 8,
#  'Anomaly Detection': 8,
#  'Dependability': 8,
#  'Hypothesis Testing': 8,
#  'Scala': 8,
#  'Gamification': 8,
#  'Business Intelligence Testing': 8,
#  'Chatbot': 8,
#  'Nanotechnology': 8,
#  'Corporate Finance': 8,
#  'Political Science': 8,
#  'Aesthetics': 8,
#  'Wireframing': 8,
#  'Interaction Design': 8,
#  'Social Media Management': 8,
#  'Performing Art': 8,
#  'Ruby': 8,
#  'Route Management': 8,
#  'Prolog': 8,
#  'Mining Engineering': 8,
#  'Ethernet': 8,
#  'Computer-Aided Manufacturing (CAM)': 8,
#  'Property Management System': 8,
#  'Opportunity Cost': 8,
#  'Security Management': 8,
#  'Cloud Storage': 8,
#  'Google Cloud Platform (GCP)': 8,
#  'Performance Engineering': 8,
#  'TikTok': 8,
#  'Bioinformatics': 7,
#  'JMP': 7,
#  'Investor Relations': 7,
#  'Engineering Physics': 7,
#  'Data Privacy Law': 7,
#  'Search Engine Marketing (SEM)': 7,
#  'Graphics Processing Unit (GPU)': 7,
#  'Data Manipulation': 7,
#  'Programming Tool': 7,
#  'Statistical Data Analysis': 7,
#  'Apache Hadoop': 7,
#  'Email Marketing': 7,
#  'Bar Chart': 7,
#  '3D Segmentation': 7,
#  'Sustainable Development': 7,
#  'Database Application': 7,
#  'PHP': 7,
#  'Formatting': 7,
#  'User Interface Design': 7,
#  'Adobe Acrobat': 7,
#  'Communications Management': 7,
#  'Consumer Privacy': 7,
#  'Asana': 7,
#  'Apache Kafka': 7,
#  'Embedded System': 7,
#  'Git': 7,
#  'Infographics': 7,
#  'Policy Analysis': 7,
#  'Buyer Engagement': 7,
#  'Channel Marketing': 7,
#  'Jin Chinese': 7,
#  'Property Maintenance': 7,
#  'Jenkins': 7,
#  'Information Science': 7,
#  'Transmission Control Protocol (TCP)': 7,
#  'Shortage': 7,
#  'Forestry': 7,
#  'Concurrency': 7,
#  'Aerospace Engineering': 7,
#  'Biomedical Engineering': 7,
#  'Motion Control': 7,
#  'NoSQL': 7,
#  'Financial Risk Management': 6,
#  'HyperText Markup Language (HTML)': 6,
#  'E Charts': 6,
#  'Graphical User Interface (GUI)': 6,
#  'Conda': 6,
#  'H2O': 6,
#  'Atlassian': 6,
#  'Computational Linguistics': 6,
#  'Printed Circuit Board': 6,
#  'Economic Statistics': 6,
#  'Cooking': 6,
#  'Payroll Services': 6,
#  'Microsoft Visio': 6,
#  'Telecommunications Engineering': 6,
#  'Data Mapping': 6,
#  'Chef': 6,
#  'Customer Service System': 6,
#  'Business Process Modelling': 6,
#  'Strategic Management': 6,
#  'Microsoft Office 365': 6,
#  'Financial Accounting': 6,
#  'WordPress': 6,
#  'Decision Process': 6,
#  'Certified Information Systems Auditor (CISA)': 6,
#  'Digital Communication': 6,
#  'B2B Marketing': 6,
#  'Animation': 6,
#  'Professional Training': 6,
#  'Cisco Router': 6,
#  'Process Control System': 6,
#  'Big Data Tool': 6,
#  'Anthropology': 6,
#  'Event Planning': 6,
#  'Environmental Technology': 6,
#  'Goods and Services': 6,
#  'Electromagnetism': 6,
#  'Decimal': 6,
#  'Safety Engineering': 6,
#  'Building Science': 6,
#  'Typography': 6,
#  'Marketing Management': 6,
#  'Network Routing': 6,
#  'Cloud Application': 6,
#  'Environmental Economics': 6,
#  'Jelastic': 6,
#  'Recommendation System': 6,
#  'Random Testing': 6,
#  'Adobe SiteCatalyst': 6,
#  'Exploratory Analysis': 5,
#  'Media Planning': 5,
#  'Contract Research Organization (CRO)': 5,
#  'Online Media': 5,
#  'Feature Engineering': 5,
#  'Vector Autoregression (VAR)': 5,
#  'Immunology': 5,
#  'Predictive Modelling': 5,
#  'Agricultural Production': 5,
#  'Campaign Optimization': 5,
#  'International Finance': 5,
#  'Ecology': 5,
#  'Facial Recognition': 5,
#  'Scientific Method': 5,
#  'Service Economics': 5,
#  'Automated Machine Learning': 5,
#  'Know Your Customer (KYC)': 5,
#  'Cost-benefit Analysis': 5,
#  'Market Segmentation': 5,
#  'Commercial Banking': 5,
#  'Data Sharing': 5,
#  'Organizational Chart': 5,
#  'Regression Testing': 5,
#  'Mobile Development': 5,
#  'National Accounts': 5,
#  'Health Economics': 5,
#  'Storyboarding': 5,
#  'Induction': 5,
#  'Consumer Behaviour': 5,
#  'Office Administration': 5,
#  'Software Quality Assurance (SQA)': 5,
#  'Game Development': 5,
#  'Game Design': 5,
#  'Chemical Processing': 5,
#  'Boosting': 5,
#  'Extreme Programming (XP)': 5,
#  'Food Production': 5,
#  'D3.js': 5,
#  'Logistic Engineering': 5,
#  'WaveMaker': 5,
#  'Expectation-Maximization (EM)': 5,
#  'Xen Cloud Platform': 5,
#  'Legal Service': 5,
#  'Cloudera': 5,
#  'Teletraffic Engineering': 5,
#  'Adminitrative Assistance': 5,
#  'Mathematical Logic': 5,
#  'Office Management': 5,
#  'Software Management': 5,
#  'Horticulture': 5,
#  'Red Hat': 5,
#  'Bookkeeping': 5,
#  'Law Practice': 5,
#  'Casino': 5,
#  'Network Optimization': 5,
#  'Storage Management': 5,
#  'Payload': 5,
#  'Machine Translation': 5,
#  'Civics': 5,
#  'Routing Protocol': 5,
#  'Redux': 5,
#  'Food Science': 5,
#  'Object-Oriented Programming (OOP)': 5,
#  'Text Recognition': 4,
#  'Economic Growth': 4,
#  'Scientific Computing': 4,
#  'Cardiology': 4,
#  'Neurology': 4,
#  'Nursing': 4,
#  'Radiology': 4,
#  'Adobe Analytics': 4,
#  'Mobile Marketing': 4,
#  'Mixed Reality': 4,
#  'Space Exploration': 4,
#  'Visual Basic For Applications (VBA)': 4,
#  'Recommendation Engine': 4,
#  'Intellectual Property Law': 4,
#  'Agronomy': 4,
#  'Generative Adversarial Network (GAN)': 4,
#  'Sentiment Analysis': 4,
#  'Visual Communication': 4,
#  'Financial Regulation': 4,
#  'Integrated Circuit': 4,
#  'Common Lisp': 4,
#  'Design Sprint': 4,
#  'PHP Development': 4,
#  'MS SQL Server': 4,
#  'Macroeconomics': 4,
#  'Health Science': 4,
#  'Dash': 4,
#  'Organizational Behaviour': 4,
#  'Semantics': 4,
#  'Pharmaceutical Manufacturing': 4,
#  'Release Engineering': 4,
#  'SAP HANA': 4,
#  'Professional Sports': 4,
#  'Terraform': 4,
#  'Socioeconomics': 4,
#  'Tor': 4,
#  'Regional Planning': 4,
#  'Digital Marketing System': 4,
#  'Social Network': 4,
#  'Distributed Denial-of-service (DDoS)': 4,
#  'Certified Information Security Manager (CISM)': 4,
#  'Part-of-speech (POS) Tagging': 4,
#  'Point of Sale (POS) Software': 4,
#  'Video Production': 4,
#  'Contract Law': 4,
#  'Behaviour Analysis': 4,
#  'IP Address': 4,
#  'Network Analysis': 4,
#  'Formal Method': 4,
#  'Track Changes': 4,
#  'SketchUp': 4,
#  'RESTful API': 4,
#  'Cleanroom': 4,
#  'Newspapers': 4,
#  'Beaker': 4,
#  'Factor Analysis': 4,
#  'Property Tax': 4,
#  'Working Capital': 4,
#  'Unix Shell': 4,
#  'Reverse Engineering': 4,
#  'Molecular Biology': 4,
#  'Visual Studio': 4,
#  'Microsoft OneNote': 4,
#  'Task Delegation': 4,
#  ...}

# %%
total = len(df_dsj) + len(df_daj) + len(df_dej) + len(df_mlej)
len(df_dsj) / total, len(df_daj) / total, len(df_dej) / total, len(df_mlej) / total
# Out:
# (0.06363191385217817,
#  0.17033773861967694,
#  0.6583455702398434,
#  0.10768477728830152)

# %%
skills = 'Presentation, Computer Science, Documentation, Testing, Microsoft Excel, Machine Learning, Agile, Architecture, Business Analysis, Automation, Artificial Intelligence (AI), Data Analysis, Consulting, Golang, Database, Quality Assurance (QA), Data Science, Microsoft PowerPoint, Software Engineering, C, Scrum, Data Management, Statistics'
skills = skills.split(', ')
s_count = {}

for s in skills:
    s_count[s] = skill_count[s

s_count
# Out:
# {'Presentation': '18.58%',
#  'Computer Science': '17.89%',
#  'Documentation': '16.94%',
#  'Testing': '14.17%',
#  'Microsoft Excel': '13.66%',
#  'Machine Learning': '13.29%',
#  'Agile': '12.04%',
#  'Architecture': '11.72%',
#  'Business Analysis': '8.59%',
#  'Automation': '8.42%',
#  'Artificial Intelligence (AI)': '8.3%',
#  'Data Analysis': '7.76%',
#  'Consulting': '7.71%',
#  'Golang': '7.59%',
#  'Database': '7.46%',
#  'Quality Assurance (QA)': '7.42%',
#  'Data Science': '6.66%',
#  'Microsoft PowerPoint': '6.66%',
#  'Software Engineering': '6.34%',
#  'C': '5.24%',
#  'Scrum': '4.67%',
#  'Data Management': '4.6%',
#  'Statistics': '4.36%'}

# %%
df_dsj.to_csv('indeed-insights/data_scientist_managers.csv', index=False)
df_daj.to_csv('indeed-insights/data_analyst_managers.csv', index=False)
df_dej.to_csv('indeed-insights/data_engineer_managers.csv', index=False)
df_mlej.to_csv('indeed-insights/machine_learning_engineer_managers.csv', index=False)

# %%
df_m = pd.read_csv('resource/Manager.csv')
df_m = df_m.drop_duplicates(subset=['Job_ID'])
print(len(df_m))
df_m.head()
# Out:
# 170
#    Unnamed: 0            Job_ID                       Job_Title  \
# 0           0  b93858aaa66216b5              Front Desk Manager
# 1           0  cb335346567f593d        Customer Service Manager
# 2           0  f311790e03591da4                      IT MANAGER
# 3           0  0c0af4a0af366017  Security Manager, Asia Pacific
# 4           0  961527fcfa62f250          STELLA – EVENT MANAGER
#
#                                        Company                       Salary  \
# 0                  Marriott International, Inc                          NaN
# 1                                      L'Oreal                          NaN
# 2  POWER STEEL & ELECTRO-PLATING WORKS SDN BHD  RM 6,000 - RM 7,999 a month
# 3                                        Wiley                          NaN
# 4                                    THE ADORA                          NaN
#
#      Country           State               Location  Metadata Date_Posted  \
# 0   Thailand  Not Applicable               Thailand       NaN  2021-05-06
# 1    Vietnam  Not Applicable  Thành phố Hồ Chí Minh       NaN  2021-05-05
# 2   Malaysia  Not Applicable              Shah Alam       NaN  2021-05-05
# 3  Singapore  Not Applicable              Singapore       NaN  2021-04-29
# 4    Vietnam  Not Applicable  Thành phố Hồ Chí Minh       NaN  2021-05-06
#
#                                          Description  \
# 0  Posting Date May 05, 2021Job Number 21042992Jo...
# 1  KEY JOB ACCOUNTABILITIES:Ensure the order-to-c...
# 2  We are an established manufacturing company in...
# 3  At Wiley, we welcome you for who you are, the ...
# 4  Mô tả công việc:Lên ý tưởng nội dung và hình ả...
#
#                                              Job_URL  \
# 0  https://th.indeed.com/rc/clk?jk=b93858aaa66216...
# 1  https://vn.indeed.com/rc/clk?jk=cb335346567f59...
# 2  https://www.indeed.com.my/rc/clk?jk=f311790e03...
# 3  https://www.indeed.com.sg/rc/clk?jk=0c0af4a0af...
# 4  https://vn.indeed.com/rc/clk?jk=961527fcfa62f2...
#
#                                     Keywords_Present Title_Keywords
# 0                                           'R', 'C'            NaN
# 1                            'C', 'CG', 'Excel', 'R'            NaN
# 2  'Microsoft Office', 'D3', 'Golang', 'C', 'Exce...            NaN
# 3                       'R', 'Microsoft Office', 'C'            NaN
# 4                         'C', 'Excel', 'PowerPoint'            NaN

# %%
df_musa = pd.read_csv('resource/Manager_USA.csv')
df_musa = df_musa.drop_duplicates(subset=['Job_ID'])
print(len(df_musa))
df_musa.head()
# Out:
# /Users/kongbinxuan/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 15412
#    Unnamed: 0            Job_ID                                    Job_Title  \
# 0           0  650c976838d7f54a                           Operations Manager
# 1           0  8400fc2fcd84644c                    Assistant Project Manager
# 2           0  06046b646b0c71d1  Corporate Store Assistant Marketing Manager
# 3           0  41fe5651c81f91a0                          Manager In Training
# 5           1  0c6442357823c030                            Warehouse Manager
#
#                         Company             Salary Country State  \
# 0                  ACE Hardware                NaN     USA    AZ
# 1  Fairbanks North Star Borough     $30.37 an hour     USA    AK
# 2                    Murphy USA                NaN     USA    AR
# 3                    McDonald's  Up to $14 an hour     USA    AL
# 5                  ACE Hardware                NaN     USA    AZ
#
#                     Location  Metadata Date_Posted  \
# 0  Prescott Valley, AZ 86314       NaN  2021-05-05
# 1        Fairbanks, AK 99701       NaN  2021-05-04
# 2        El Dorado, AR 71730       NaN  2021-05-05
# 3        Stevenson, AL 35772       NaN  2021-05-06
# 5  Prescott Valley, AZ 86314       NaN  2021-05-06
#
#                                          Description  \
# 0  We have an exciting opportunity for a Operatio...
# 1  POSITION TITLE:  Assistant Project ManagerSTAT...
# 2  The Corporate Store Assistant Manager (ASM) wi...
# 3  Are you looking for a long-term career withgre...
# 5  PURPOSE AND SCOPE:The Warehouse Manager will b...
#
#                                              Job_URL  \
# 0  https://www.indeed.com/company/Ace-Hardware/jo...
# 1  https://www.indeed.com/company/Fairbanks-North...
# 2  https://www.indeed.com/rc/clk?jk=06046b646b0c7...
# 3  https://www.indeed.com/rc/clk?jk=41fe5651c81f9...
# 5  https://www.indeed.com/rc/clk?jk=0c6442357823c...
#
#                                     Keywords_Present Title_Keywords
# 0  'SAP', 'Excel', 'Microsoft Office', 'C', 'R', ...            NaN
# 1            'R', 'Microsoft Office', 'C', 'AutoCAD'            NaN
# 2                                           'R', 'C'            NaN
# 3                                           'R', 'C'            NaN
# 5                                           'R', 'C'            NaN

# %%
df_m2 = df_m.dropna(subset=['Description'])
df_m2 = df_m.drop_duplicates(subset=['Description'])
len(df_m2)
# Out:
# 149

# %%
df_musa2 = df_musa.dropna(subset=['Description'])
df_musa2 = df_musa.drop_duplicates(subset=['Description'])
len(df_musa2)
# Out:
# 436

# %%
df_m2j = extract_skills_all(df_m2)
df_m2j.head()
# Out:
# 7 jobs processed. Time taken: 0:00:16.367012
# 14 jobs processed. Time taken: 0:00:15.432640
# 21 jobs processed. Time taken: 0:00:10.965708
# 28 jobs processed. Time taken: 0:00:19.574557
# 35 jobs processed. Time taken: 0:00:14.091822
# 42 jobs processed. Time taken: 0:00:16.882405
# 49 jobs processed. Time taken: 0:00:13.077847
# 56 jobs processed. Time taken: 0:00:18.615172
# 63 jobs processed. Time taken: 0:00:10.135088
# 70 jobs processed. Time taken: 0:00:17.145819
# 77 jobs processed. Time taken: 0:00:13.359265
# 84 jobs processed. Time taken: 0:00:13.703946
# 91 jobs processed. Time taken: 0:00:24.502049
# 98 jobs processed. Time taken: 0:00:15.934104
# 105 jobs processed. Time taken: 0:00:15.277584
# 112 jobs processed. Time taken: 0:00:12.556205
# 119 jobs processed. Time taken: 0:00:13.679552
# 126 jobs processed. Time taken: 0:00:18.760842
# 133 jobs processed. Time taken: 0:00:12.343077
# 140 jobs processed. Time taken: 0:00:13.434660
# 147 jobs processed. Time taken: 0:00:11.196514
# Total time taken: 0:05:20.301286
#              job_id                           title  \
# 0  b93858aaa66216b5              Front Desk Manager
# 1  cb335346567f593d        Customer Service Manager
# 2  f311790e03591da4                      IT MANAGER
# 3  0c0af4a0af366017  Security Manager, Asia Pacific
# 4  961527fcfa62f250          STELLA – EVENT MANAGER
#
#                                        company    country date_posted  \
# 0                  Marriott International, Inc   Thailand  2021-05-06
# 1                                      L'Oreal    Vietnam  2021-05-05
# 2  POWER STEEL & ELECTRO-PLATING WORKS SDN BHD   Malaysia  2021-05-05
# 3                                        Wiley  Singapore  2021-04-29
# 4                                    THE ADORA    Vietnam  2021-05-06
#
#                                          description  \
# 0  Posting Date May 05, 2021Job Number 21042992Jo...
# 1  KEY JOB ACCOUNTABILITIES:Ensure the order-to-c...
# 2  We are an established manufacturing company in...
# 3  At Wiley, we welcome you for who you are, the ...
# 4  Mô tả công việc:Lên ý tưởng nội dung và hình ả...
#
#                                        indeed_skills  \
# 0                                           'R', 'C'
# 1                            'C', 'CG', 'Excel', 'R'
# 2  'Microsoft Office', 'D3', 'Golang', 'C', 'Exce...
# 3                       'R', 'Microsoft Office', 'C'
# 4                         'C', 'Excel', 'PowerPoint'
#
#                                               skills
# 0  [Accounting, Accuracy, Asset Management, Coach...
# 1  [Accuracy, Change Management, Collaboration, C...
# 2  [Analysis, Analytical Thinking, Audit, Budget,...
# 3  [Collaboration, Creativity, Customer Service, ...
# 4  [C, Design, Microsoft Excel, Microsoft PowerPo...

# %%
df_musa2j = extract_skills_all(df_musa2)
df_musa2j.head()
# Out:
# 21 jobs processed. Time taken: 0:01:00.830605
# 42 jobs processed. Time taken: 0:01:11.067973
# 63 jobs processed. Time taken: 0:01:24.587132
# 84 jobs processed. Time taken: 0:01:09.385854
# 105 jobs processed. Time taken: 0:01:16.604754
# 126 jobs processed. Time taken: 0:01:03.175028
# 147 jobs processed. Time taken: 0:01:25.282795
# 168 jobs processed. Time taken: 0:00:55.207781
# 189 jobs processed. Time taken: 0:01:08.355705
# 210 jobs processed. Time taken: 0:01:15.352851
# 231 jobs processed. Time taken: 0:01:22.021525
# 252 jobs processed. Time taken: 0:01:17.943607
# 273 jobs processed. Time taken: 0:01:11.040318
# 294 jobs processed. Time taken: 0:01:10.057737
# 315 jobs processed. Time taken: 0:01:14.616535
# 336 jobs processed. Time taken: 0:01:23.722176
# 357 jobs processed. Time taken: 0:00:58.714897
# 378 jobs processed. Time taken: 0:01:40.596053
# 399 jobs processed. Time taken: 0:01:10.983391
# 420 jobs processed. Time taken: 0:01:15.558137
# Total time taken: 0:25:32.271599
#              job_id                                        title  \
# 0  650c976838d7f54a                           Operations Manager
# 1  8400fc2fcd84644c                    Assistant Project Manager
# 2  06046b646b0c71d1  Corporate Store Assistant Marketing Manager
# 3  41fe5651c81f91a0                          Manager In Training
# 4  0c6442357823c030                            Warehouse Manager
#
#                         company country date_posted  \
# 0                  ACE Hardware     USA  2021-05-05
# 1  Fairbanks North Star Borough     USA  2021-05-04
# 2                    Murphy USA     USA  2021-05-05
# 3                    McDonald's     USA  2021-05-06
# 4                  ACE Hardware     USA  2021-05-06
#
#                                          description  \
# 0  We have an exciting opportunity for a Operatio...
# 1  POSITION TITLE:  Assistant Project ManagerSTAT...
# 2  The Corporate Store Assistant Manager (ASM) wi...
# 3  Are you looking for a long-term career withgre...
# 4  PURPOSE AND SCOPE:The Warehouse Manager will b...
#
#                                        indeed_skills  \
# 0  'SAP', 'Excel', 'Microsoft Office', 'C', 'R', ...
# 1            'R', 'Microsoft Office', 'C', 'AutoCAD'
# 2                                           'R', 'C'
# 3                                           'R', 'C'
# 4                                           'R', 'C'
#
#                                               skills
# 0  [Analytical, Data Analysis, Hardware, Leadersh...
# 1  [Accuracy, Administration, Architectural Engin...
# 2  [Administration, Closing, Customer Service, Ma...
# 3  [Insurance, Management, Metals, Microsoft Exce...
# 4  [Budget, Customer Service, Ergonomics, Hardwar...

# %%
def get_skill_count(df, d):
    for _, row in df.iterrows():
        for s in row['skills']:
            d.append({'Skill': s, 'Count': 1})

skill_count = []

get_skill_count(df_dsj, skill_count)
get_skill_count(df_daj, skill_count)
get_skill_count(df_dej, skill_count)
get_skill_count(df_mlej, skill_count)
get_skill_count(df_m2j, skill_count)
get_skill_count(df_musa2j, skill_count)
get_skill_count(df_m2j, skill_count)
get_skill_count(df_musa2j, skill_count)

df_sc = pd.DataFrame.from_dict(skill_count)
df_sc.head()
# Out:
#                 Skill  Count
# 0  Applied Statistics      1
# 1          Automation      1
# 2       Cloud Service      1
# 3    Cloud Technology      1
# 4       Collaboration      1

# %%
df_all = df_dsj.append(df_daj).append(df_dej).append(df_mlej).append(df_m2j).append(df_m2j).append(df_musa2j).append(df_musa2j)
df_all = df_all.sample(frac=1).reset_index(drop=True)
df_all.head()
# Out:
#                                                title  \
# 0  assistant manager design engineer (electronic ...
# 1                                    Factory Manager
# 2  Manager, Enrichment/Service Excellence, Custom...
# 3                     Manufacturing Engineer manager
# 4                             Senior Product Manager
#
#                                          company    country date_posted  \
# 0  บริษัท จัดหางาน คะเรียลิงค์ (ประเทศไทย) จำกัด   Thailand  2020-05-23
# 1                            AA PRODUCTS SDN BHD   Malaysia  2021-05-06
# 2                                           Grab  Singapore  2021-05-06
# 3                              Hot Shot Staffing        USA  2020-04-10
# 4                                         Hopper        USA  2020-05-23
#
#                                          description  \
# 0  รายละเอียดงานรูปแบบงาน   งานประจำจำนวนที่รับ  ...
# 1  Manufacturing managers plan, oversee and direc...
# 2  Get to know our Team :We design and provide pr...
# 3  • Hire, train, and supervise engineering staff...
# 4  at hopper  we’re on a mission to make booking ...
#
#                                indeed_skills  \
# 0                                       None
# 1                                        'C'
# 2  'R', 'Excel', 'Golang', 'PowerPoint', 'C'
# 3                                   'C', 'R'
# 4                                       None
#
#                                               skills            job_id
# 0  [Communication, Design, Electronics, English, ...               NaN
# 1        [Budget, Engineering, Manufacturing, Sales]  040c1448846b6eb3
# 2  [Analytical, Audit, Automation, Banking, Brain...  b0fbfc0eb67911d5
# 3  [Accuracy, Analytical, Budget, Business Admini...               NaN
# 4  [Airlines, Banking, Big Data, Construction, Cr...               NaN

# %%
df_all.loc[df_all['title'].str.contains('data', case=False)]
# Out:
#                                                   title  \
# 21                             Data & AI Senior Manager
# 25                             Data / Analytics Manager
# 31                          Data Analytics & BI Manager
# 36    Program Manager, Data Science and Applied Comp...
# 45                      Data Modeling Assistant Manager
# ...                                                 ...
# 5207                         Engineering Manager - Data
# 5223         Sr. Engineering Manager - Data & Analytics
# 5224  Global Compensation Manager / Data Analyst, Re...
# 5227                   Data & Applied Scientist Manager
# 5238         Digital - Product Manager - Data Platforms
#
#                                       company    country date_posted  \
# 21                    Monroe Consulting Group  Indonesia  2021-03-26
# 25                     Bioworld Merchandising        USA  2020-05-28
# 31                            Michael Page TH   Thailand  2021-04-13
# 36    University of Wisconsin Extended Campus        USA  2020-05-09
# 45                               Argyll Scott   Thailand  2020-05-19
# ...                                       ...        ...         ...
# 5207                                    Convr        USA  2020-05-23
# 5223                              ProClinical        USA  2020-05-14
# 5224                     Wilbur-Ellis Company        USA  2020-05-12
# 5227                                Microsoft        USA  2020-04-10
# 5238                 FactSet Research Systems        USA  2020-04-10
#
#                                             description  \
# 21    Data & AI Strategy Senior ManagerAccenture is ...
# 25    bioworld merchandising is a leading design and...
# 31    Reputable with top-notch products diverse comp...
# 36    NOTE: The University of Wisconsin System is en...
# 45    one of the leading insurance companies is recr...
# ...                                                 ...
# 5207  about us convr is a growing startup in the ins...
# 5223  proclinical is currently recruiting for a seni...
# 5224  do you have experience in north america and as...
# 5227  Core Services Engineering builds and manages t...
# 5238  The Platform Product Development team is respo...
#
#                                           indeed_skills  \
# 21    'C', 'Machine Learning', 'Artificial Intellige...
# 25                                       'Excel', 'SQL'
# 31                            'Data Analysis', 'R', 'C'
# 36                                             'C', 'R'
# 45                               'Python', 'SAS', 'SQL'
# ...                                                 ...
# 5207                                               None
# 5223                                           'C', 'R'
# 5224                                  'C', 'Excel', 'R'
# 5227                                     'C', 'Go', 'R'
# 5238                                           'C', 'R'
#
#                                                  skills job_id
# 21    [Analysis, Analytical, Artificial Intelligence...    NaN
# 25    [Analytical, Apparel, Artificial Intelligence ...    NaN
# 31    [Analytical, Business Intelligence (BI), Data ...    NaN
# 36    [Administrative Law, Array, Budget, Collaborat...    NaN
# 45    [Analytical Thinking, Applied Mathematics, Com...    NaN
# ...                                                 ...    ...
# 5207  [Agile, Architecture, Communication, D3.js, Da...    NaN
# 5223  [Agile, Analytical, Apache Kafka, Apache Spark...    NaN
# 5224  [Agricultural Production, Analysis, Architectu...    NaN
# 5227  [Business Acumen, Communication, Data Analytic...    NaN
# 5238  [Agile, Application Programming Interface (API...    NaN
#
# [341 rows x 8 columns]

# %%
df_all['country'].value_counts(normalize=True)
# Out:
# USA            0.713470
# Singapore      0.094178
# Malaysia       0.064117
# Thailand       0.047374
# Vietnam        0.033866
# Indonesia      0.025495
# Philippines    0.021499
# Name: country, dtype: float64

# %%
total = len(df_dsj) + len(df_daj) + len(df_dej) + len(df_mlej) + len(df_m2j) * 2 + len(df_musa2j) * 2
total
# Out:
# 5256

# %%
df_sc2 = df_sc.groupby('Skill').sum().reset_index()
df_sc2['Percent'] = df_sc2['Count'].apply(lambda x: round(x / total * 100, 2))
df_sc2 = df_sc2.sort_values(by='Count', ascending=False)
df_sc2.head()
# Out:
#                    Skill  Count  Percent
# 777           Leadership   1854    35.27
# 275        Communication   1849    35.18
# 1434            Training   1829    34.80
# 424               Design   1624    30.90
# 1108  Project Management   1308    24.89

# %%
df_sc2.to_csv('manager_skills.csv')
