# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt 
import seaborn as sns
from sqlalchemy import create_engine
from datetime import datetime as dt
from nltk import ngrams
from difflib import get_close_matches as gcm
from secrets import secrets

# %%
skills = pd.read_csv('skills_db2/skill.csv')
skills.head()
# Out:
#    skill_id                skill
# 0         1      Applied Science
# 1         2  Arts and Humanities
# 2         3             Business
# 3         4     Computer Science
# 4         5         Data Science

# %%
sk_list = skills['skill'].tolist()
len(sk_list)
# Out:
# 3031

# %%
query = """
select Job_ID, Job_Title, Company, Country, Date_Posted, Description, Keywords_Present, Title_Keywords 
from {}
where Date_Posted > '2020-06-01'
and Description != 'No Description'
"""

def extract_df(job):
    df = pd.read_sql(query.format(job), engine)
    df.drop_duplicates(inplace=True)
    print('Number of rows', len(df))
    return df

def extract_skills_all(df):
    i = 0
    job_info_list = []
    initial = dt.now()
    interval = dt.now()
    print_every = 200
    for _, job in df.iterrows():
        i += 1
        if i % print_every == 0:
            print("{} jobs processed. Time taken: {}".format(i, dt.now() - interval))
            interval = dt.now()
        all_info = job['Job_Title'] + ' ' + job['Description']
        skills = extract_skills(all_info)
        job_info_list.append({
            'title': job['Job_Title'],
            'company': job['Company'],
            'country': job['Country'],
            'date_posted': job['Date_Posted'],
            'description': job['Description'],
            'title_keywords': job['Title_Keywords'],
            'indeed_skills': job['Keywords_Present'],
            'skills': skills,
            'no_skills': len(skills)
        })
    print("Total time taken: {}".format(dt.now() - initial))
    return pd.DataFrame.from_dict(job_info_list)

def extract_skills(info):
    # Remove ordered list with alphabets: a), b), c),...
    words = re.sub(r'[\s\t\n]+[a-zA-Z\s*]\)+', ' ', info)
    words = re.sub('[\n|,|.|/|\(|\)]', ' ', words).lower().split()
    bigrams = [' '.join(g) for g in ngrams(words, 2)]
    trigrams = [' '.join(g) for g in ngrams(words, 3)]
    results = []
    for skill in sk_list:
        s = skill.lower()
        if '(' in s:
            abb = s[s.find("(")+1:s.find(")")]
            if abb in info:
                continue
            s = re.sub(r"[\(].*?[\)]", "", s)
        s2 = s.split()
        if len(s2) == 1:
            if len(gcm(s, words, cutoff=0.9)) > 0:
                results.append(skill)
        elif len(s2) == 2:
            if len(gcm(s, bigrams, cutoff=0.9)) > 0:
                results.append(skill)
        elif len(s2) == 3:
            if len(gcm(s, trigrams, cutoff=0.85)) > 0:
                results.append(skill)
        else:
            if len(gcm(s, trigrams, cutoff=0.8)) > 0:
                results.append(skill)
    return results

# %%
engine = create_engine(secrets['indeed_db'])
df_ds = extract_df('Data_Scientist')
df_ds.head()
# Out:
# Number of rows 2284
#              Job_ID                 Job_Title  \
# 0  dce076954b6def5d            Data Scientist
# 1  0af114638b83542d            Data Scientist
# 2  482f223f74269b38            Data Scientist
# 3  23570b7ea0a5ecbf  Data Scientist Executive
# 4  caacc69df1a0c0e0            Data Scientist
#
#                                          Company   Country Date_Posted  \
# 0  Mission Consultancy Services Malaysia Sdn Bhd  Malaysia  2020-07-26
# 1                                        AirAsia  Malaysia  2020-08-15
# 2                           CareerMaster Sdn Bhd  Malaysia  2020-07-26
# 3                                GENO Management  Malaysia  2020-08-18
# 4                     PLUS SOLAR SYSTEMS SDN BHD  Malaysia  2020-07-26
#
#                                          Description  \
# 0  Identify valuable data sources and automate co...
# 1  Job DescriptionOverviewThis role will responsi...
# 2  Position to be based in Kuala Lumpur.We are re...
# 3  Position : Data Scientists ExecutiveLocation :...
# 4  Work With Stakeholders Throughout The Organiza...
#
#                                     Keywords_Present Title_Keywords
# 0  'C', 'C++', 'Excel', 'Hadoop', 'Java', 'R', 'S...           None
# 1                                           'C', 'R'           None
# 2  'C', 'GIS', 'Go', 'Python', 'R', 'SQL', 'Stati...           None
# 3  'AWS', 'C', 'Go', 'Python', 'R', 'Regression',...           None
# 4                                                'C'           None

# %%
df_dsj = extract_skills_all(df_ds)
df_dsj.head()
# Out:
# 200 jobs processed. Time taken: 0:08:31.487232
# 400 jobs processed. Time taken: 0:07:25.305195
# 600 jobs processed. Time taken: 0:06:36.810810
# 800 jobs processed. Time taken: 0:07:56.447118
# 1000 jobs processed. Time taken: 0:07:52.935527
# 1200 jobs processed. Time taken: 0:07:40.275196
# 1400 jobs processed. Time taken: 0:07:16.074752
# 1600 jobs processed. Time taken: 0:07:18.611516
# 1800 jobs processed. Time taken: 0:08:08.216351
# 2000 jobs processed. Time taken: 0:08:19.897735
# 2200 jobs processed. Time taken: 0:08:00.242933
# Total time taken: 1:28:24.364609
#                       title                                        company  \
# 0            Data Scientist  Mission Consultancy Services Malaysia Sdn Bhd
# 1            Data Scientist                                        AirAsia
# 2            Data Scientist                           CareerMaster Sdn Bhd
# 3  Data Scientist Executive                                GENO Management
# 4            Data Scientist                     PLUS SOLAR SYSTEMS SDN BHD
#
#     country date_posted                                        description  \
# 0  Malaysia  2020-07-26  Identify valuable data sources and automate co...
# 1  Malaysia  2020-08-15  Job DescriptionOverviewThis role will responsi...
# 2  Malaysia  2020-07-26  Position to be based in Kuala Lumpur.We are re...
# 3  Malaysia  2020-08-18  Position : Data Scientists ExecutiveLocation :...
# 4  Malaysia  2020-07-26  Work With Stakeholders Throughout The Organiza...
#
#   title_keywords                                      indeed_skills  \
# 0           None  'C', 'C++', 'Excel', 'Hadoop', 'Java', 'R', 'S...
# 1           None                                           'C', 'R'
# 2           None  'C', 'GIS', 'Go', 'Python', 'R', 'SQL', 'Stati...
# 3           None  'AWS', 'C', 'Go', 'Python', 'R', 'Regression',...
# 4           None                                                'C'
#
#                                               skills  no_skills
# 0  [Business, Analytical, Communication, Developm...         27
# 1  [Business, Accuracy, Processing, Product, A/B ...         21
# 2  [Business, Computer Science, Microsoft, Proces...         30
# 3  [Business, Data Science, Analytical, Business ...         39
# 4  [Business, Accuracy, Development, Marketing, P...          9

# %%
df_dsj.to_csv('indeed-insights.csv', index=False)

# %%
df_da = extract_df('Data_Analyst')
df_da.head()
# Out:
# Number of rows 8069
#              Job_ID                Job_Title  \
# 0  dce076954b6def5d           Data Scientist
# 1  66201e0720bcd228    Customer Data Analyst
# 2  edad2206e0edd9c4  Data Management Analyst
# 3  2ac6b0ad8a608de0             Data Analyst
# 4  8a57fc4f1e969cf3        Data Analyst, SQL
#
#                                          Company   Country Date_Posted  \
# 0  Mission Consultancy Services Malaysia Sdn Bhd  Malaysia  2020-07-26
# 1                  Senheng Electric (KL) Sdn Bhd  Malaysia  2020-07-26
# 2               Samsung SDS Asia Pacific Pte Ltd  Malaysia  2020-08-17
# 3                   Asia Online Publishing Group  Malaysia  2020-08-22
# 4                                      Grab Taxi  Malaysia  2020-08-26
#
#                                          Description  \
# 0  Identify valuable data sources and automate co...
# 1  Manages the company’s customer loyalty program...
# 2  Responsibility:Handling whole process related ...
# 3  Job Description: Ability to analyze and accura...
# 4  Get to know the Role :Collaborate with product...
#
#                                     Keywords_Present Title_Keywords
# 0  'C', 'C++', 'Excel', 'Hadoop', 'Java', 'R', 'S...           None
# 1              'C', 'Excel', 'Go', 'R', 'Statistics'           None
# 2                                           'C', 'R'           None
# 3                            'C', 'Excel', 'Go', 'R'           None
# 4  'C', 'CG', 'Excel', 'R', 'SQL', 'Statistics', ...           None

# %%
df_dsa = extract_skills_all(df_da)
df_dsa.head()
# Out:
# 200 jobs processed. Time taken: 0:07:38.574058
# 400 jobs processed. Time taken: 0:08:03.659577
# 600 jobs processed. Time taken: 0:07:57.090188
# 800 jobs processed. Time taken: 0:07:50.273669
# 1000 jobs processed. Time taken: 0:06:23.421924
# 1200 jobs processed. Time taken: 0:07:18.990292
# 1400 jobs processed. Time taken: 0:07:23.920834
# 1600 jobs processed. Time taken: 0:08:01.485652
# 1800 jobs processed. Time taken: 0:06:33.304374
# 2000 jobs processed. Time taken: 0:07:21.665184
# 2200 jobs processed. Time taken: 0:07:42.693433
# 2400 jobs processed. Time taken: 0:05:43.516511
# 2600 jobs processed. Time taken: 0:06:39.831240
# 2800 jobs processed. Time taken: 0:07:19.932316
# 3000 jobs processed. Time taken: 0:07:31.625077
# 3200 jobs processed. Time taken: 0:08:33.047903
# 3400 jobs processed. Time taken: 0:06:17.887602
# 3600 jobs processed. Time taken: 0:07:17.592962
# 3800 jobs processed. Time taken: 0:09:14.081823
# 4000 jobs processed. Time taken: 0:06:09.387244
# 4200 jobs processed. Time taken: 0:06:42.515711
# 4400 jobs processed. Time taken: 0:07:37.124591
# 4600 jobs processed. Time taken: 0:08:35.352573
# 4800 jobs processed. Time taken: 0:07:10.812936
# 5000 jobs processed. Time taken: 0:07:32.710113
# 5200 jobs processed. Time taken: 0:08:29.267999
# 5400 jobs processed. Time taken: 0:09:26.073795
# 5600 jobs processed. Time taken: 0:07:01.814594
# 5800 jobs processed. Time taken: 0:08:15.941024
# 6000 jobs processed. Time taken: 0:09:01.979189
# 6200 jobs processed. Time taken: 0:07:42.409927
# 6400 jobs processed. Time taken: 0:07:09.926402
# 6600 jobs processed. Time taken: 0:08:03.832324
# 6800 jobs processed. Time taken: 0:08:47.258066
# 7000 jobs processed. Time taken: 0:06:36.997650
# 7200 jobs processed. Time taken: 0:07:25.653700
# 7400 jobs processed. Time taken: 0:08:17.587465
# 7600 jobs processed. Time taken: 0:07:59.752933
# 7800 jobs processed. Time taken: 0:07:30.789913
# 8000 jobs processed. Time taken: 0:07:53.033888
# Total time taken: 5:07:36.005283
#                      title                                        company  \
# 0           Data Scientist  Mission Consultancy Services Malaysia Sdn Bhd
# 1    Customer Data Analyst                  Senheng Electric (KL) Sdn Bhd
# 2  Data Management Analyst               Samsung SDS Asia Pacific Pte Ltd
# 3             Data Analyst                   Asia Online Publishing Group
# 4        Data Analyst, SQL                                      Grab Taxi
#
#     country date_posted                                        description  \
# 0  Malaysia  2020-07-26  Identify valuable data sources and automate co...
# 1  Malaysia  2020-07-26  Manages the company’s customer loyalty program...
# 2  Malaysia  2020-08-17  Responsibility:Handling whole process related ...
# 3  Malaysia  2020-08-22  Job Description: Ability to analyze and accura...
# 4  Malaysia  2020-08-26  Get to know the Role :Collaborate with product...
#
#   title_keywords                                      indeed_skills  \
# 0           None  'C', 'C++', 'Excel', 'Hadoop', 'Java', 'R', 'S...
# 1           None              'C', 'Excel', 'Go', 'R', 'Statistics'
# 2           None                                           'C', 'R'
# 3           None                            'C', 'Excel', 'Go', 'R'
# 4           None  'C', 'CG', 'Excel', 'R', 'SQL', 'Statistics', ...
#
#                                               skills  no_skills
# 0  [Business, Analytical, Communication, Developm...         27
# 1  [Business, Administration, Business Strategy, ...         15
# 2  [Business, Computer Science, Accounting, Admin...         17
# 3  [Excel, Processing, Database, Database System,...         10
# 4  [Business, Computer Science, Analytical, Colla...         29

# %%
df_dsa.to_csv('indeed-insights/data_analyst.csv', index=False)

# %%
df_de = extract_df('Data_Engineer')
df_de.head()
# Out:
# Number of rows 9322
#              Job_ID                         Job_Title  \
# 0  4a0d4e1f4736c11b                 Software Engineer
# 1  d2771a7dd040fe7e                 Planning Engineer
# 2  08c07ebc566bde97               Electrical Engineer
# 3  50adbda0e1c6ec38  Maintenance Master Data Engineer
# 4  925ba321ef02d64b               Industrial Engineer
#
#                           Company   Country Date_Posted  \
# 0               Enovision Sdn Bbd  Malaysia  2020-07-26
# 1  Grand Dynamic Builders Sdn Bhd  Malaysia  2020-08-26
# 2       Easun Engineering Sdn Bhd  Malaysia  2020-08-17
# 3                    Air Products  Malaysia  2020-08-19
# 4                      KJCF Group  Malaysia  2020-08-19
#
#                                          Description  \
# 0  Are you getting boring to work in office every...
# 1  Responsibilities: -o To assist Planning Manage...
# 2  Diploma or Degree in Electrical Engineering· 2...
# 3  PurposeAs a member of the Global Master Data T...
# 4  Packaging is part and parcel of marketing a pr...
#
#                                    Keywords_Present Title_Keywords
# 0  'Artificial Intelligence', 'C', 'C++', 'Go', 'R'           None
# 1                                   'C', 'R', 'SAS'           None
# 2                                          'C', 'R'           None
# 3                                 'C', 'Excel', 'R'           None
# 4                 'C', 'Excel', 'Factor', 'Go', 'R'           None

# %%
df_dej = extract_skills_all(df_de)
df_dej.head()
# Out:
# 200 jobs processed. Time taken: 0:07:02.167641
# 400 jobs processed. Time taken: 0:07:12.173663
# 600 jobs processed. Time taken: 0:07:36.249357
# 800 jobs processed. Time taken: 0:07:44.981286
# 1000 jobs processed. Time taken: 0:07:23.198946
# 1200 jobs processed. Time taken: 0:07:53.841603
# 1400 jobs processed. Time taken: 0:06:56.944614
# 1600 jobs processed. Time taken: 0:06:58.121925
# 1800 jobs processed. Time taken: 0:06:36.549107
# 2000 jobs processed. Time taken: 0:06:36.890634
# 2200 jobs processed. Time taken: 0:07:07.737757
# 2400 jobs processed. Time taken: 0:06:03.714149
# 2600 jobs processed. Time taken: 0:07:04.841540
# 2800 jobs processed. Time taken: 0:06:49.909986
# 3000 jobs processed. Time taken: 0:41:08.402092
# 3200 jobs processed. Time taken: 1:16:49.509436
# 3400 jobs processed. Time taken: 0:06:28.527476
# 3600 jobs processed. Time taken: 0:06:24.852576
# 3800 jobs processed. Time taken: 0:06:36.242494
# 4000 jobs processed. Time taken: 0:07:39.315882
# 4200 jobs processed. Time taken: 0:06:58.162860
# 4400 jobs processed. Time taken: 0:06:00.387078
# 4600 jobs processed. Time taken: 0:06:51.809625
# 4800 jobs processed. Time taken: 0:07:45.695017
# 5000 jobs processed. Time taken: 0:07:21.624445
# 5200 jobs processed. Time taken: 0:07:36.237436
# 5400 jobs processed. Time taken: 0:06:35.168117
# 5600 jobs processed. Time taken: 0:06:23.999907
# 5800 jobs processed. Time taken: 0:06:49.962360
# 6000 jobs processed. Time taken: 0:06:35.659769
# 6200 jobs processed. Time taken: 0:07:59.608864
# 6400 jobs processed. Time taken: 0:08:46.649683
# 6600 jobs processed. Time taken: 0:09:25.755488
# 6800 jobs processed. Time taken: 0:09:41.889570
# 7000 jobs processed. Time taken: 0:09:57.647995
# 7200 jobs processed. Time taken: 0:10:02.622378
# 7400 jobs processed. Time taken: 0:08:56.259985
# 7600 jobs processed. Time taken: 0:10:41.428128
# 7800 jobs processed. Time taken: 0:10:30.777976
# 8000 jobs processed. Time taken: 0:09:39.523816
# 8200 jobs processed. Time taken: 0:09:02.268344
# 8400 jobs processed. Time taken: 0:09:22.248473
# 8600 jobs processed. Time taken: 0:10:21.255944
# 8800 jobs processed. Time taken: 0:09:56.951873
# 9000 jobs processed. Time taken: 0:09:42.052238
# 9200 jobs processed. Time taken: 0:10:01.989639
# Total time taken: 7:53:08.221444
#                               title                         company   country  \
# 0                 Software Engineer               Enovision Sdn Bbd  Malaysia
# 1                 Planning Engineer  Grand Dynamic Builders Sdn Bhd  Malaysia
# 2               Electrical Engineer       Easun Engineering Sdn Bhd  Malaysia
# 3  Maintenance Master Data Engineer                    Air Products  Malaysia
# 4               Industrial Engineer                      KJCF Group  Malaysia
#
#   date_posted                                        description  \
# 0  2020-07-26  Are you getting boring to work in office every...
# 1  2020-08-26  Responsibilities: -o To assist Planning Manage...
# 2  2020-08-17  Diploma or Degree in Electrical Engineering· 2...
# 3  2020-08-19  PurposeAs a member of the Global Master Data T...
# 4  2020-08-19  Packaging is part and parcel of marketing a pr...
#
#   title_keywords                                     indeed_skills  \
# 0           None  'Artificial Intelligence', 'C', 'C++', 'Go', 'R'
# 1           None                                   'C', 'R', 'SAS'
# 2           None                                          'C', 'R'
# 3           None                                 'C', 'Excel', 'R'
# 4           None                 'C', 'Excel', 'Factor', 'Go', 'R'
#
#                                               skills  no_skills
# 0  [Computer Science, Analytical, Development, Pr...         30
# 1  [Analytical, Communication, Construction, Indu...         27
# 2  [Communication, Nonverbal Communication, Plann...         10
# 3  [Business, Accuracy, Communication, Documentat...         34
# 4  [Analytical, Communication, Decision Making, D...         30

# %%
df_dej.to_csv('indeed-insights/data_engineer.csv', index=False)

# %%
engine = create_engine(secrets['indeed_db'])
df_mle = extract_df('Machine_Learning_Engineer')
df_mle.head()
# Out:
# Number of rows 2372
#              Job_ID                                     Job_Title  \
# 0  4becba66641bee03                     Machine Learning Engineer
# 1  3b94feea299270df    Machine Learning Engineer / Data Scientist
# 2  5cb1009fe6976657  Artificial Intelligence AI Software Engineer
# 3  f98889dc5f47b972                    Software Engineer, Backend
# 4  66b3d489fb6431d7                      Executive, Data Engineer
#
#                   Company   Country Date_Posted  \
# 0  3E Accounting Malaysia  Malaysia  2020-07-27
# 1     Neural Technologies  Malaysia  2020-07-27
# 2  3E Accounting Malaysia  Malaysia  2020-07-27
# 3               Grab Taxi  Malaysia  2020-08-26
# 4                 AirAsia  Malaysia  2020-08-04
#
#                                          Description  \
# 0  Position TitleMachine Learning Engineer – Acco...
# 1  Main Accountabilities & Responsibilities:Apply...
# 2  Position TitleArtificial Intelligence AI Softw...
# 3  Get to know the Role:As such, we are seeking t...
# 4  We are all different - one talent to another -...
#
#                                     Keywords_Present Title_Keywords
# 0                       'C', 'Machine Learning', 'R'           None
# 1            'C', 'Go', 'Hive', 'Python', 'R', 'SQL'           None
# 2  'Artificial Intelligence', 'C', 'Go', 'Machine...           None
# 3  'AWS', 'C', 'C++', 'Elasticsearch', 'Erlang', ...           None
# 4     'BigQuery', 'C', 'Excel', 'Python', 'R', 'SQL'           None

# %%
df_mlej = extract_skills_all(df_mle)
df_mlej.head()
# Out:
# 200 jobs processed. Time taken: 0:07:09.458571
# 400 jobs processed. Time taken: 0:06:32.570051
# 600 jobs processed. Time taken: 0:07:07.645440
# 800 jobs processed. Time taken: 0:07:33.678055
# 1000 jobs processed. Time taken: 0:07:22.380791
# 1200 jobs processed. Time taken: 0:08:13.954454
# 1400 jobs processed. Time taken: 0:07:58.255262
# 1600 jobs processed. Time taken: 0:08:27.147819
# 1800 jobs processed. Time taken: 0:08:20.285030
# 2000 jobs processed. Time taken: 0:07:56.394660
# 2200 jobs processed. Time taken: 0:08:58.032652
# Total time taken: 1:32:38.731267
#                                           title                 company  \
# 0                     Machine Learning Engineer  3E Accounting Malaysia
# 1    Machine Learning Engineer / Data Scientist     Neural Technologies
# 2  Artificial Intelligence AI Software Engineer  3E Accounting Malaysia
# 3                    Software Engineer, Backend               Grab Taxi
# 4                      Executive, Data Engineer                 AirAsia
#
#     country date_posted                                        description  \
# 0  Malaysia  2020-07-27  Position TitleMachine Learning Engineer – Acco...
# 1  Malaysia  2020-07-27  Main Accountabilities & Responsibilities:Apply...
# 2  Malaysia  2020-07-27  Position TitleArtificial Intelligence AI Softw...
# 3  Malaysia  2020-08-26  Get to know the Role:As such, we are seeking t...
# 4  Malaysia  2020-08-04  We are all different - one talent to another -...
#
#   title_keywords                                      indeed_skills  \
# 0           None                       'C', 'Machine Learning', 'R'
# 1           None            'C', 'Go', 'Hive', 'Python', 'R', 'SQL'
# 2           None  'Artificial Intelligence', 'C', 'Go', 'Machine...
# 3           None  'AWS', 'C', 'C++', 'Elasticsearch', 'Erlang', ...
# 4           None     'BigQuery', 'C', 'Excel', 'Python', 'R', 'SQL'
#
#                                               skills  no_skills
# 0  [Computer Science, Accounting, Email, Service,...         19
# 1  [Computer Science, Commercial, Communication, ...         14
# 2  [Computer Science, Accounting, Development, Do...         19
# 3  [Computer Science, Analytical, Communication, ...         42
# 4  [Business, Data Science, Airlines, Analytical,...         51

# %%
df_mlej.to_csv('indeed-insights/machine_learning_engineer.csv', index=False)
