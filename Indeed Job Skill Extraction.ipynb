# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt 
import seaborn as sns
from sqlalchemy import create_engine
from datetime import datetime as dt
from secrets import secrets
from skill_api import extract_skills, extract_ignore

# %%
# Skills
df_skills = pd.read_csv('skills_db2/skill.csv')
SKILLS = df_skills['Skill'].unique().tolist()
# Redundant skills
df_redskills = pd.read_excel('skills/Other Skills.xlsx')
RED_SKILLS = df_redskills['Skill'].unique().tolist()
# Duplicate skills
df_dupskills = pd.read_excel('skills/Other Skills.xlsx', sheet_name='Duplicates')
DUP_SKILLS = df_dupskills.set_index('Skill').to_dict()['Parent']
SKILLS.extend(list(DUP_SKILLS.keys()))

# %%
query = """
select Job_ID, Job_Title, Company, Country, Date_Posted, Description, Keywords_Present, Title_Keywords 
from {}
where Date_Posted > '2020-06-01'
and Description != 'No Description'
"""

def extract_df(job):
    df = pd.read_sql(query.format(job), engine)
    df.drop_duplicates(inplace=True)
    no_skill = df['Keywords_Present'].isna()
    df['Num_Skill'] = 0
    df.loc[~no_skill, 'Num_Skill'] = df.loc[~no_skill, 'Keywords_Present'].apply(lambda x: len(x.split(',')))
    df = df.loc[df['Num_Skill'] <= 3]
    print('Number of rows', len(df))
    return df

def extract_skills_all(df):
    i = 0
    job_info_list = []
    initial = dt.now()
    interval = dt.now()
    print_every = int(len(df) / 20)
    for _, job in df.iterrows():
        i += 1
        if i % print_every == 0:
            print("{} jobs processed. Time taken: {}".format(i, dt.now() - interval))
            interval = dt.now()
        all_info = job['Job_Title'] + ' ' + job['Description']
        all_skills = extract_skills(all_info, SKILLS)
        keep_skills, _ = extract_ignore(all_skills, RED_SKILLS, DUP_SKILLS)
        keep_skills.sort()
        # ignore_skills.sort()
        job_info_list.append({
            'title': job['Job_Title'],
            'company': job['Company'],
            'country': job['Country'],
            'date_posted': job['Date_Posted'],
            'description': job['Description'],
            'indeed_skills': job['Keywords_Present'],
            'skills': keep_skills,
        })
    print("Total time taken: {}".format(dt.now() - initial))
    return pd.DataFrame.from_dict(job_info_list)

# %%
engine = create_engine(secrets['indeed_db'])
df_ds = extract_df('Data_Scientist')
df_ds.head()
# Out:
# Number of rows 673
#               Job_ID                            Job_Title  \
# 1   0af114638b83542d                       Data Scientist
# 4   caacc69df1a0c0e0                       Data Scientist
# 41  aa123e23bb46c569                            Scientist
# 46  5bd740a8c7cdc204  Data & Advanced Analytics Architect
# 49  05d59d7d9c321ca9                           AI Analyst
#
#                                               Company   Country Date_Posted  \
# 1                                             AirAsia  Malaysia  2020-08-15
# 4                          PLUS SOLAR SYSTEMS SDN BHD  Malaysia  2020-07-26
# 41                                            Mediven  Malaysia  2020-07-26
# 46                                             Orsted  Malaysia  2020-08-14
# 49  ACE Digital, Ace Resource Advisory Services Sd...  Malaysia  2020-08-19
#
#                                           Description        Keywords_Present  \
# 1   Job DescriptionOverviewThis role will responsi...                'C', 'R'
# 4   Work With Stakeholders Throughout The Organiza...                     'C'
# 41  MedivenTM aspires to be a provider of innovati...                'C', 'R'
# 46  Imagine a future where you architect revolutio...      'C', 'Python', 'R'
# 49  Key Responsibilities:Assist Data Scientists in...  'C', 'R', 'Statistics'
#
#    Title_Keywords  Num_Skill
# 1            None          2
# 4            None          1
# 41           None          2
# 46           None          3
# 49           None          3

# %%
df_dsj = extract_skills_all(df_ds)
df_dsj.head()
# Out:
# 33 jobs processed. Time taken: 0:01:47.458453
# 66 jobs processed. Time taken: 0:01:17.021420
# 99 jobs processed. Time taken: 0:01:10.464390
# 132 jobs processed. Time taken: 0:01:07.321380
# 165 jobs processed. Time taken: 0:01:16.280228
# 198 jobs processed. Time taken: 0:01:58.571726
# 231 jobs processed. Time taken: 0:01:16.134256
# 264 jobs processed. Time taken: 0:01:12.380399
# 297 jobs processed. Time taken: 0:01:31.025138
# 330 jobs processed. Time taken: 0:01:27.038425
# 363 jobs processed. Time taken: 0:01:04.263817
# 396 jobs processed. Time taken: 0:01:13.438820
# 429 jobs processed. Time taken: 0:01:29.788202
# 462 jobs processed. Time taken: 0:01:27.361734
# 495 jobs processed. Time taken: 0:01:40.655782
# 528 jobs processed. Time taken: 0:01:19.395035
# 561 jobs processed. Time taken: 0:01:34.437820
# 594 jobs processed. Time taken: 0:01:20.666006
# 627 jobs processed. Time taken: 0:00:33.139818
# 660 jobs processed. Time taken: 0:01:13.757290
# Total time taken: 0:27:28.133012
#                                  title  \
# 0                       Data Scientist
# 1                       Data Scientist
# 2                            Scientist
# 3  Data & Advanced Analytics Architect
# 4                           AI Analyst
#
#                                              company   country date_posted  \
# 0                                            AirAsia  Malaysia  2020-08-15
# 1                         PLUS SOLAR SYSTEMS SDN BHD  Malaysia  2020-07-26
# 2                                            Mediven  Malaysia  2020-07-26
# 3                                             Orsted  Malaysia  2020-08-14
# 4  ACE Digital, Ace Resource Advisory Services Sd...  Malaysia  2020-08-19
#
#                                          description           indeed_skills  \
# 0  Job DescriptionOverviewThis role will responsi...                'C', 'R'
# 1  Work With Stakeholders Throughout The Organiza...                     'C'
# 2  MedivenTM aspires to be a provider of innovati...                'C', 'R'
# 3  Imagine a future where you architect revolutio...      'C', 'Python', 'R'
# 4  Key Responsibilities:Assist Data Scientists in...  'C', 'R', 'Statistics'
#
#                                               skills
# 0  [A/B Testing, Accuracy, Analytical, Anomaly De...
# 1  [Accuracy, Algorithm, Data Gathering, Database...
# 2  [Accuracy, Analysis, Analytical, Biotechnology...
# 3  [Analytical, Architecture, Arts, Coaching, Com...
# 4  [Analytical, Artificial Intelligence (AI), Clo...

# %%
df_dsj.to_csv('indeed-insights/data_scientist2.csv', index=False)

# %%
df_da = extract_df('Data_Analyst')
df_da.head()
# Out:
# Number of rows 4206
#               Job_ID                       Job_Title  \
# 2   edad2206e0edd9c4         Data Management Analyst
# 8   7aec3cff1d32c3e0                    Data Analyst
# 9   1ff2afdb40430056         Data Management Analyst
# 10  ed48c162d7db36c5                    Data Analyst
# 11  b3e757a2c8e7ecf8  Know Your Client (KYC) Analyst
#
#                              Company   Country Date_Posted  \
# 2   Samsung SDS Asia Pacific Pte Ltd  Malaysia  2020-08-17
# 8                  Canvass Luuminate  Malaysia  2020-08-12
# 9                        AstraZeneca  Malaysia  2020-08-21
# 10                             SWIFT  Malaysia  2020-08-13
# 11                     Deutsche Bank  Malaysia  2020-08-19
#
#                                           Description   Keywords_Present  \
# 2   Responsibility:Handling whole process related ...           'C', 'R'
# 8   - Data administration- Assist founders on dail...           'C', 'R'
# 9   AstraZeneca is a global, innovation-driven bio...     'C', 'Go', 'R'
# 10  About the RoleIn line with the company and div...  'C', 'Excel', 'R'
# 11  The Know Your Client (KYC) Operator is respons...           'C', 'R'
#
#    Title_Keywords  Num_Skill
# 2            None          2
# 8            None          2
# 9            None          3
# 10           None          3
# 11           None          2

# %%
df_dsa = extract_skills_all(df_da)
df_dsa.head()
# Out:
# 210 jobs processed. Time taken: 0:08:09.004624
# 420 jobs processed. Time taken: 0:08:53.844750
# 630 jobs processed. Time taken: 0:07:15.065782
# 840 jobs processed. Time taken: 0:08:41.575859
# 1050 jobs processed. Time taken: 0:08:04.682529
# 1260 jobs processed. Time taken: 0:07:19.264402
# 1470 jobs processed. Time taken: 0:07:32.063397
# 1680 jobs processed. Time taken: 0:08:47.507725
# 1890 jobs processed. Time taken: 0:07:24.935709
# 2100 jobs processed. Time taken: 0:07:53.305211
# 2310 jobs processed. Time taken: 0:07:25.557392
# 2520 jobs processed. Time taken: 0:08:07.604161
# 2730 jobs processed. Time taken: 0:08:40.922121
# 2940 jobs processed. Time taken: 0:08:10.687705
# 3150 jobs processed. Time taken: 0:08:11.434869
# 3360 jobs processed. Time taken: 0:07:32.758726
# 3570 jobs processed. Time taken: 0:06:12.425841
# 3780 jobs processed. Time taken: 0:07:28.938498
# 3990 jobs processed. Time taken: 0:06:49.200784
# 4200 jobs processed. Time taken: 0:07:05.088214
# Total time taken: 2:35:58.531517
#                             title                           company   country  \
# 0         Data Management Analyst  Samsung SDS Asia Pacific Pte Ltd  Malaysia
# 1                    Data Analyst                 Canvass Luuminate  Malaysia
# 2         Data Management Analyst                       AstraZeneca  Malaysia
# 3                    Data Analyst                             SWIFT  Malaysia
# 4  Know Your Client (KYC) Analyst                     Deutsche Bank  Malaysia
#
#   date_posted                                        description  \
# 0  2020-08-17  Responsibility:Handling whole process related ...
# 1  2020-08-12  - Data administration- Assist founders on dail...
# 2  2020-08-21  AstraZeneca is a global, innovation-driven bio...
# 3  2020-08-13  About the RoleIn line with the company and div...
# 4  2020-08-19  The Know Your Client (KYC) Operator is respons...
#
#        indeed_skills                                             skills
# 0           'C', 'R'  [Accounting, Administration, Analysis, Compute...
# 1           'C', 'R'                          [Database Administration]
# 2     'C', 'Go', 'R'  [Brand Management, Business Administration, Bu...
# 3  'C', 'Excel', 'R'  [Accuracy, Analysis, Analytical, Budget, Commu...
# 4           'C', 'R'  [Accuracy, Banking, Brand Management, Effectiv...

# %%
df_dsa.to_csv('indeed-insights/data_analyst2.csv', index=False)

# %%
df_de = extract_df('Data_Engineer')
df_de.head()
# Out:
# Number of rows 4971
#              Job_ID                         Job_Title  \
# 1  d2771a7dd040fe7e                 Planning Engineer
# 2  08c07ebc566bde97               Electrical Engineer
# 3  50adbda0e1c6ec38  Maintenance Master Data Engineer
# 5  f529772747f229c4                     Data Engineer
# 7  2e84c8b017751381                 Proposal Engineer
#
#                           Company   Country Date_Posted  \
# 1  Grand Dynamic Builders Sdn Bhd  Malaysia  2020-08-26
# 2       Easun Engineering Sdn Bhd  Malaysia  2020-08-17
# 3                    Air Products  Malaysia  2020-08-19
# 5                  Axrail Sdn Bhd  Malaysia  2020-07-26
# 7       Precision Control Sdn Bhd  Malaysia  2020-08-04
#
#                                          Description       Keywords_Present  \
# 1  Responsibilities: -o To assist Planning Manage...        'C', 'R', 'SAS'
# 2  Diploma or Degree in Electrical Engineering· 2...               'C', 'R'
# 3  PurposeAs a member of the Global Master Data T...      'C', 'Excel', 'R'
# 5  Data engineers are an essential part of our an...  'AWS', 'R', 'Tableau'
# 7  · To provide pre-sales to customers.· Collabor...         'C', 'Go', 'R'
#
#   Title_Keywords  Num_Skill
# 1           None          3
# 2           None          2
# 3           None          3
# 5           None          3
# 7           None          3

# %%
df_dej = extract_skills_all(df_de)
df_dej.head()
# Out:
# 248 jobs processed. Time taken: 0:08:24.520942
# 496 jobs processed. Time taken: 0:09:04.752090
# 744 jobs processed. Time taken: 0:08:38.314209
# 992 jobs processed. Time taken: 0:07:33.047894
# 1240 jobs processed. Time taken: 0:07:42.373214
# 1488 jobs processed. Time taken: 0:08:16.943567
# 1736 jobs processed. Time taken: 0:07:17.542231
# 1984 jobs processed. Time taken: 0:07:22.964189
# 2232 jobs processed. Time taken: 0:08:23.632669
# 2480 jobs processed. Time taken: 0:07:59.648578
# 2728 jobs processed. Time taken: 0:09:03.807301
# 2976 jobs processed. Time taken: 0:07:41.267650
# 3224 jobs processed. Time taken: 0:07:52.400941
# 3472 jobs processed. Time taken: 0:08:29.487179
# 3720 jobs processed. Time taken: 0:09:01.837624
# 3968 jobs processed. Time taken: 0:07:51.955621
# 4216 jobs processed. Time taken: 0:07:47.963288
# 4464 jobs processed. Time taken: 0:08:26.175348
# 4712 jobs processed. Time taken: 0:07:36.152229
# 4960 jobs processed. Time taken: 0:08:20.051774
# Total time taken: 2:43:18.690907
#                               title                         company   country  \
# 0                 Planning Engineer  Grand Dynamic Builders Sdn Bhd  Malaysia
# 1               Electrical Engineer       Easun Engineering Sdn Bhd  Malaysia
# 2  Maintenance Master Data Engineer                    Air Products  Malaysia
# 3                     Data Engineer                  Axrail Sdn Bhd  Malaysia
# 4                 Proposal Engineer       Precision Control Sdn Bhd  Malaysia
#
#   date_posted                                        description  \
# 0  2020-08-26  Responsibilities: -o To assist Planning Manage...
# 1  2020-08-17  Diploma or Degree in Electrical Engineering· 2...
# 2  2020-08-19  PurposeAs a member of the Global Master Data T...
# 3  2020-07-26  Data engineers are an essential part of our an...
# 4  2020-08-04  · To provide pre-sales to customers.· Collabor...
#
#            indeed_skills                                             skills
# 0        'C', 'R', 'SAS'  [Analytical, Civil Engineering, Communication,...
# 1               'C', 'R'  [Assembly, Electrical Engineering, Electronic ...
# 2      'C', 'Excel', 'R'  [Accuracy, Automation, Chemical Engineering, C...
# 3  'AWS', 'R', 'Tableau'  [Amazon EMR, Amazon S3, Amazon Web Service (AW...
# 4         'C', 'Go', 'R'  [Collaboration, Communication, Design, Electro...

# %%
df_dej.to_csv('indeed-insights/data_engineer2.csv', index=False)

# %%
engine = create_engine(secrets['indeed_db'])
df_mle = extract_df('Machine_Learning_Engineer')
df_mle.head()
# Out:
# Number of rows 458
#               Job_ID                                          Job_Title  \
# 0   4becba66641bee03                          Machine Learning Engineer
# 6   28aefe300cf14774                                  Robotics Engineer
# 27  aa8f2e607f63e88b                             Maintenance Technician
# 31  f7837ed0331dac73  Special Training Programme for Project Enginee...
# 32  386bd8e583629cab                         Programming & SMT Engineer
#
#                              Company   Country Date_Posted  \
# 0             3E Accounting Malaysia  Malaysia  2020-07-27
# 6   NDR Medical Technology Sdn. Bhd.  Malaysia  2020-08-25
# 27              JACOBS DOUWE EGBERTS  Malaysia  2020-08-22
# 31                  RWNA Engineering  Malaysia  2020-07-27
# 32           NALA EMPLOYMENT SDN BHD  Malaysia  2020-07-29
#
#                                           Description  \
# 0   Position TitleMachine Learning Engineer – Acco...
# 6   Job Responsibilities:Conduct research to deter...
# 27  Company DescriptionIt’s amazing what can happe...
# 31  TRAINING PROGRAMME TITLE:Preparation for Proje...
# 32  ResponsibilityPROGRAMMING-- to prepare, to con...
#
#                 Keywords_Present Title_Keywords  Num_Skill
# 0   'C', 'Machine Learning', 'R'           None          3
# 6              'C', 'Excel', 'R'           None          3
# 27                      'C', 'R'           None          2
# 31                      'C', 'R'           None          2
# 32                      'C', 'R'           None          2

# %%
df_mlej = extract_skills_all(df_mle)
df_mlej.head()
# Out:
# 22 jobs processed. Time taken: 0:00:49.093413
# 44 jobs processed. Time taken: 0:00:43.951808
# 66 jobs processed. Time taken: 0:00:43.885003
# 88 jobs processed. Time taken: 0:00:40.798607
# 110 jobs processed. Time taken: 0:00:51.184228
# 132 jobs processed. Time taken: 0:00:44.716359
# 154 jobs processed. Time taken: 0:00:45.444496
# 176 jobs processed. Time taken: 0:00:50.546184
# 198 jobs processed. Time taken: 0:01:04.047386
# 220 jobs processed. Time taken: 0:00:57.697364
# 242 jobs processed. Time taken: 0:01:12.792243
# 264 jobs processed. Time taken: 0:00:56.434899
# 286 jobs processed. Time taken: 0:00:47.415359
# 308 jobs processed. Time taken: 0:00:54.252302
# 330 jobs processed. Time taken: 0:00:52.611237
# 352 jobs processed. Time taken: 0:01:09.746094
# 374 jobs processed. Time taken: 0:00:50.470090
# 396 jobs processed. Time taken: 0:00:56.928567
# 418 jobs processed. Time taken: 0:00:42.239570
# 440 jobs processed. Time taken: 0:00:38.992700
# Total time taken: 0:18:16.471403
#                                                title  \
# 0                          Machine Learning Engineer
# 1                                  Robotics Engineer
# 2                             Maintenance Technician
# 3  Special Training Programme for Project Enginee...
# 4                         Programming & SMT Engineer
#
#                             company   country date_posted  \
# 0            3E Accounting Malaysia  Malaysia  2020-07-27
# 1  NDR Medical Technology Sdn. Bhd.  Malaysia  2020-08-25
# 2              JACOBS DOUWE EGBERTS  Malaysia  2020-08-22
# 3                  RWNA Engineering  Malaysia  2020-07-27
# 4           NALA EMPLOYMENT SDN BHD  Malaysia  2020-07-29
#
#                                          description  \
# 0  Position TitleMachine Learning Engineer – Acco...
# 1  Job Responsibilities:Conduct research to deter...
# 2  Company DescriptionIt’s amazing what can happe...
# 3  TRAINING PROGRAMME TITLE:Preparation for Proje...
# 4  ResponsibilityPROGRAMMING-- to prepare, to con...
#
#                   indeed_skills  \
# 0  'C', 'Machine Learning', 'R'
# 1             'C', 'Excel', 'R'
# 2                      'C', 'R'
# 3                      'C', 'R'
# 4                      'C', 'R'
#
#                                               skills
# 0  [Accounting, Azure Machine Learning, Computer ...
# 1  [Analytical, Applied Physics, Communication, C...
# 2  [Coaching, Imagine, Machinery, Mechanical Engi...
# 3  [Assembly, Communication, Control System, ISO ...
# 4  [Analysis, Process Engineering, Profiling, Pro...

# %%
df_mlej.to_csv('indeed-insights/machine_learning_engineer2.csv', index=False)

# %%
engine.dispose()

# %%
df_all = df_dsj.append(df_dsa)
df_all = df_all.append(df_dej)
df_all = df_all.append(df_mlej)
df_all.head()
# Out:
#                                  title  \
# 0                       Data Scientist
# 1                       Data Scientist
# 2                            Scientist
# 3  Data & Advanced Analytics Architect
# 4                           AI Analyst
#
#                                              company   country date_posted  \
# 0                                            AirAsia  Malaysia  2020-08-15
# 1                         PLUS SOLAR SYSTEMS SDN BHD  Malaysia  2020-07-26
# 2                                            Mediven  Malaysia  2020-07-26
# 3                                             Orsted  Malaysia  2020-08-14
# 4  ACE Digital, Ace Resource Advisory Services Sd...  Malaysia  2020-08-19
#
#                                          description           indeed_skills  \
# 0  Job DescriptionOverviewThis role will responsi...                'C', 'R'
# 1  Work With Stakeholders Throughout The Organiza...                     'C'
# 2  MedivenTM aspires to be a provider of innovati...                'C', 'R'
# 3  Imagine a future where you architect revolutio...      'C', 'Python', 'R'
# 4  Key Responsibilities:Assist Data Scientists in...  'C', 'R', 'Statistics'
#
#                                               skills
# 0  [A/B Testing, Accuracy, Analytical, Anomaly De...
# 1  [Accuracy, Algorithm, Data Gathering, Database...
# 2  [Accuracy, Analysis, Analytical, Biotechnology...
# 3  [Analytical, Architecture, Arts, Coaching, Com...
# 4  [Analytical, Artificial Intelligence (AI), Clo...

# %%
skill_dict = {}

for _, row in df_all.iterrows():
    skills = row['skills']
    for skill in skills:
        if skill in skill_dict.keys():
            skill_dict[skill] += 1
        else:
            skill_dict[skill] = 1

# %%
dict(sorted(skill_dict.items(), key=lambda item: item[1], reverse=True))
# Out:
# {'Communication': 3262,
#  'Analytical': 2721,
#  'Design': 2659,
#  'Training': 2150,
#  'Information Technology (IT)': 2085,
#  'English': 1948,
#  'Analysis': 1877,
#  'Problem Solving': 1875,
#  'TestNG': 1865,
#  'Reporting': 1811,
#  'Documentation': 1653,
#  'Market': 1646,
#  'Testing': 1621,
#  'Management': 1615,
#  'Engineering': 1544,
#  'Manufacturing': 1419,
#  'Sales': 1298,
#  'Presentation': 1228,
#  'Platform': 1222,
#  'Finance': 1207,
#  'Research': 1203,
#  'Leadership': 1186,
#  'Computer Science': 1184,
#  'Innovation': 1179,
#  'Microsoft Excel': 1136,
#  'Network': 1133,
#  'Project Management': 1081,
#  'Email': 1043,
#  'Electronics': 1007,
#  'Audit': 997,
#  'Collaboration': 981,
#  'Business Analysis': 965,
#  'Security': 906,
#  'Data Analysis': 900,
#  'Writing': 853,
#  'Database': 807,
#  'Processing': 797,
#  'Law': 794,
#  'Automation': 770,
#  'Quality Assurance (QA)': 761,
#  'Marketing': 741,
#  'Budget': 740,
#  'C': 732,
#  'Administration': 723,
#  'Human Resource (HR)': 720,
#  'Microsoft Access': 711,
#  'Accounting': 680,
#  'Insurance': 680,
#  'Hardware': 674,
#  'Accuracy': 654,
#  'Written Communication': 630,
#  'Business Process': 619,
#  'Ad Design': 616,
#  'Construction': 584,
#  'Customer Service': 583,
#  'Technical Support': 559,
#  'Networking': 549,
#  'Interpreter': 541,
#  'Mechanical Engineering': 536,
#  'Trade': 526,
#  'Artificial Intelligence (AI)': 519,
#  'Decision Making': 512,
#  'Electronic Engineering': 506,
#  'Agile': 504,
#  'Consulting': 503,
#  'Configuration': 501,
#  'Electrical Engineering': 499,
#  'Machine Learning': 498,
#  'Microsoft Office': 497,
#  'Product Development': 495,
#  'Architecture': 494,
#  'Creatio': 490,
#  'Procurement': 487,
#  'Transformer': 486,
#  'Data Analytics': 480,
#  'SAP': 478,
#  'Banking': 476,
#  'Semiconductors': 464,
#  'Research and Development (R&D)': 442,
#  'Repair': 422,
#  'Brand Management': 421,
#  'Windows': 404,
#  'Business Intelligence (BI)': 399,
#  'Translation': 392,
#  'Investment': 390,
#  'Microsoft PowerPoint': 383,
#  'Assembly': 382,
#  'Logistics': 373,
#  'Software Engineering': 367,
#  'Economics': 367,
#  'Change Management': 365,
#  'Negotiation': 361,
#  'Selection': 355,
#  'Data Management': 353,
#  'Programming': 351,
#  'Automotive': 343,
#  'Statistics': 342,
#  'Organizational Skill': 341,
#  'Teamwork': 341,
#  'Subject Matter Expert (SME)': 341,
#  'User Experience (UX)': 339,
#  'Privacy': 338,
#  'Nonverbal Communication': 336,
#  'Chemical': 335,
#  'eCommerce': 335,
#  'Time Management': 335,
#  'Play': 327,
#  'Division': 323,
#  'Financial Services': 318,
#  'Modelling': 317,
#  'Operating System': 315,
#  'Enterprise Resource Planning (ERP)': 307,
#  'Sentry': 303,
#  'Quality Control': 303,
#  'Data Science': 302,
#  'Process Engineering': 302,
#  'Coaching': 301,
#  'Golang': 301,
#  'Information System': 298,
#  'Structured Query Language (SQL)': 294,
#  'Risk Management': 293,
#  'Scheduling': 287,
#  'Mechatronics': 286,
#  'Creativity': 283,
#  'Root Cause Analysis': 282,
#  'Intellectual Property (IP)': 281,
#  'IT Operations': 281,
#  'Objective-C': 278,
#  'Dashboard': 275,
#  'Forecasting': 274,
#  'Effective Communication': 274,
#  'Closing': 273,
#  'Internet': 272,
#  'Firewall': 272,
#  'Computer Engineering': 270,
#  'Telecommunication': 270,
#  'Customer Experience': 266,
#  'Logic': 263,
#  'R': 261,
#  'Internet Protocol (IP)': 259,
#  'Sustainability': 259,
#  'Visualization': 257,
#  'Methodology': 256,
#  'Table': 253,
#  'Video': 250,
#  'Protocol': 248,
#  'Retail': 248,
#  'User Interface (UI)': 244,
#  'Customer Relationship Management (CRM)': 239,
#  'Product Management': 238,
#  'Fabrication': 238,
#  'History': 236,
#  'Healthcare': 234,
#  'Microsoft': 232,
#  'Application Programming Interface (API)': 228,
#  'Coding': 226,
#  'Big Data': 226,
#  'Business Development': 226,
#  'Algorithm': 221,
#  'Transportation': 221,
#  'Chemistry': 218,
#  'Router': 217,
#  'Production Process': 217,
#  'Software Development': 215,
#  'Manufacturing Engineering': 212,
#  'Asset Management': 210,
#  'Critical Thinking': 209,
#  'Mathematics': 209,
#  'Indonesian': 207,
#  'Saving': 203,
#  'Team Building': 202,
#  'Scrum': 201,
#  'LeSS': 200,
#  'Support Engineering': 200,
#  '.NET Framework': 197,
#  'Compiler': 194,
#  'Recommendations AI': 189,
#  'AutoCAD': 189,
#  'Industrial Engineering': 187,
#  'Software Tool': 185,
#  'Marketing Research': 185,
#  'Quality Management': 181,
#  'Media': 180,
#  'Complexity': 180,
#  'Variable': 178,
#  'Development Tools': 177,
#  'Business Administration': 177,
#  'Oracle': 177,
#  'Quality Engineering': 176,
#  'Data Mining': 171,
#  'Market Research': 170,
#  'Japanese': 169,
#  'Recruiting': 168,
#  'Mapping': 167,
#  'German': 166,
#  'Virtual Reality (VR)': 166,
#  'Chemical Engineering': 165,
#  'Machinery': 165,
#  'Searching': 164,
#  'Information Security': 164,
#  'Chart': 163,
#  'Debugging': 159,
#  'Apache Spark': 158,
#  'Civil Engineering': 158,
#  'Data Visualization': 157,
#  'Medium': 156,
#  'Data Structure': 155,
#  'Computing': 152,
#  'Business Operations': 152,
#  'Classification': 150,
#  'Physics': 149,
#  'Internet of Things (IoT)': 147,
#  'Business Acumen': 147,
#  'Linux': 146,
#  'Jira': 146,
#  'Template': 146,
#  'Rally': 146,
#  'Vietnamese': 143,
#  'Systems Engineering': 142,
#  'Network Security': 141,
#  'Life Science': 140,
#  'Python': 139,
#  'Information Threat': 138,
#  'Data Gathering': 136,
#  'Instrumentation': 136,
#  'Programming Language': 136,
#  'Business Plan': 136,
#  'Materials Science': 134,
#  'Microsoft Outlook': 134,
#  'Outsourcing': 133,
#  'Scripting': 133,
#  'Analytical Thinking': 131,
#  'Ethics': 131,
#  'Autonomous Vehicle': 131,
#  'Salesforce': 130,
#  'Unix': 129,
#  'Financial Statement': 129,
#  'Control System': 128,
#  'Social Media': 127,
#  'Neural Network': 127,
#  'Prototyping': 126,
#  'Sports': 125,
#  'Software Development Life Cycle (SDLC)': 125,
#  'Statistical Analysis': 123,
#  'Literature': 123,
#  'Continuous Integration (CI)': 123,
#  'Lean Software Development': 123,
#  'Business Strategy': 123,
#  'Oral Communication': 123,
#  'Facebook': 122,
#  'Requirements Gathering': 122,
#  'Performance Management': 121,
#  'Cybersecurity': 120,
#  'Business Management': 118,
#  'Incident Management': 118,
#  'Domain Name System (DNS)': 117,
#  'Property': 116,
#  'Balance Sheet': 116,
#  'Front End': 115,
#  'Empathy': 114,
#  'Service Management': 113,
#  'Microsoft Power BI': 113,
#  'System Analysis': 113,
#  'Digital Marketing': 112,
#  'Extract Transform Load (ETL)': 112,
#  'System Administration': 111,
#  'Accounts Payable': 111,
#  'Box': 110,
#  'Augmented Reality (AR)': 110,
#  'Microsoft Word': 110,
#  'Business Model': 110,
#  'Competition': 109,
#  'Data Modelling': 109,
#  'Investment Banking': 109,
#  'Supply Chain Management': 108,
#  'Image': 108,
#  'Information and Communications Technology (ICT)': 108,
#  'Management Information System (MIS)': 108,
#  'Technical Documentation': 107,
#  'Robotics': 107,
#  'Gradle': 106,
#  'Commodity': 105,
#  'Cisco Certified Network Associate (CCNA)': 105,
#  'Supply Chain Risk Management': 104,
#  'Benchmarking': 104,
#  'Transmission Control Protocol (TCP)': 104,
#  'Autoregressive (AR) Model': 102,
#  'Wireframes': 102,
#  'Product Marketing': 102,
#  'Big Data Analysis': 101,
#  'Dataset': 101,
#  'jQuery': 101,
#  'ISO 9001': 100,
#  'Software Application': 99,
#  'Product Roadmap': 98,
#  'Equity': 96,
#  'Meteorology': 96,
#  'Peripheral': 96,
#  'Graph': 96,
#  'iOS': 96,
#  'Account Receivable': 95,
#  'Data Privacy': 95,
#  'Metrology': 94,
#  'Workday': 94,
#  'Regression': 93,
#  'Blogging': 92,
#  'Metals': 92,
#  'Web Application': 92,
#  'LinkedIn': 91,
#  'Poster': 91,
#  'Software as a Service (SaaS)': 91,
#  'Virtualization': 91,
#  'Vulnerability': 91,
#  'News': 88,
#  'Financial Market': 88,
#  'Korean': 87,
#  'Agile Methodology': 86,
#  'Java': 86,
#  'Advertising': 84,
#  'Twitter': 84,
#  'Strategic Planning': 84,
#  'Malay': 84,
#  'Securities': 84,
#  'Oil and Gas': 83,
#  'Array': 83,
#  'A/B Testing': 81,
#  'DevOps': 81,
#  'Urban Engineering': 81,
#  'Market Analysis': 79,
#  'Microsoft Azure': 78,
#  'Reinforcement Learning': 78,
#  'Correlation': 78,
#  'Molecular Biology': 77,
#  'Software System': 77,
#  'Knowledge Management': 77,
#  'Optics': 76,
#  'Sequence': 75,
#  'Vmware': 75,
#  'Continuous Delivery (CD)': 74,
#  'Imagine': 74,
#  'Requirement Analysis': 74,
#  'Certified Information Systems Security Professional (CISSP)': 74,
#  'Real Estate': 74,
#  'Sales Operations': 73,
#  'Utility': 73,
#  'Security Engineering': 73,
#  'Links': 72,
#  'Pivot Table': 72,
#  'Performance Review': 72,
#  'Business Analytics': 71,
#  'Project Planning': 71,
#  'Cloud Computing': 70,
#  'Aerospace': 70,
#  'C#': 70,
#  'Entertainment': 70,
#  'Web Design': 70,
#  'Problem Management': 70,
#  'Product Knowledge': 69,
#  'Boosting': 69,
#  'Software Testing': 69,
#  'Financial Modelling': 69,
#  'Sampling': 67,
#  'Plastics': 67,
#  'Client Relations': 67,
#  'Software Package': 67,
#  'Software Design': 67,
#  'UX Design': 66,
#  'Android': 66,
#  'Dynamic Host Configuration Protocol (DHCP)': 66,
#  'Biochemistry': 65,
#  'Business Intelligence Tool': 65,
#  'Product Testing': 65,
#  'Philosophy': 65,
#  'Derivative': 65,
#  'Configuration Management': 65,
#  'Adaptability': 64,
#  'Swift': 64,
#  'Amazon Web Service (AWS)': 64,
#  'Medicine': 63,
#  'Code Review': 63,
#  'Border Gateway Protocol (BGP)': 63,
#  'Reasoning': 62,
#  'Management Consulting': 62,
#  'Risk Analysis': 61,
#  'Nice': 61,
#  'Business Ethics': 61,
#  'Processor': 61,
#  'Big Data Analytics': 61,
#  'Node.js': 60,
#  'Generally Accepeted Accounting Principles (GAAP)': 60,
#  'Profiling': 59,
#  'Know Your Customer (KYC)': 59,
#  'Mergers and Acquisitions (M&A)': 59,
#  'Data Acquisition': 59,
#  'Integrated Circuit': 59,
#  'Credit Risk': 58,
#  'Information Management': 58,
#  'Outreach': 58,
#  'Public Relations (PR)': 58,
#  'Data Mapping': 58,
#  'Control Engineering': 58,
#  'Deep Learning': 57,
#  'Population': 57,
#  'Sustainable Development': 57,
#  'Computer-Aided Manufacturing (CAM)': 57,
#  'Operations Management': 57,
#  'Usability Engineering': 57,
#  'Web Application Development': 56,
#  'Publishing': 56,
#  'Brainstorming': 56,
#  'Visual Basic For Applications (VBA)': 56,
#  'React': 56,
#  'Predictive Model': 55,
#  'Radio': 55,
#  'Data Security': 55,
#  'UI Design': 55,
#  'Tableau': 54,
#  'Calendar': 54,
#  'Power Management': 54,
#  'Biology': 53,
#  'Shell': 53,
#  'Manufacturing Operations': 53,
#  'Printed Circuit Board': 53,
#  'Mining': 52,
#  'Data Architecture': 52,
#  'Variance Analysis': 52,
#  'Computer Hardware': 52,
#  'Biotechnology': 51,
#  'Technical Writing': 51,
#  'Editing': 51,
#  'JMP': 51,
#  'Sketch': 51,
#  'Fraction': 51,
#  'Access Control': 51,
#  'Materials Engineering': 50,
#  'Currency': 50,
#  'Forth': 50,
#  'Cleanroom': 49,
#  'Telecommunications Engineering': 49,
#  'Data Engineering': 48,
#  'Informatics': 47,
#  'Financial Management': 47,
#  'Agriculture': 47,
#  'Scorecard': 47,
#  'Software Requirement': 47,
#  'Statistical Data Analysis': 47,
#  'HyperText Markup Language (HTML)': 47,
#  'Software Architecture': 47,
#  'Industrial Automation': 47,
#  'Data Cleansing': 47,
#  'Branding': 46,
#  'Cascading Style Sheet (CSS)': 46,
#  'Quantitative Research': 46,
#  'Regression Testing': 46,
#  'Data Pipeline': 45,
#  'International Business': 45,
#  'Web Development': 45,
#  'Flowchart': 45,
#  'Photography': 45,
#  'Malware': 45,
#  'Network Management': 45,
#  'Process Model': 45,
#  'Leadership Development': 44,
#  'Youtube': 44,
#  'Blockchain': 44,
#  'Confluence': 44,
#  'Security Management': 44,
#  'Payment Processing': 44,
#  'VOIP': 44,
#  'Search Engine Marketing (SEM)': 43,
#  'C++': 43,
#  'Network Architecture': 43,
#  'Encryption': 43,
#  'Welding': 43,
#  'Cloud Technology': 42,
#  'Polymerase chain reaction (PCR)': 42,
#  'Chemical Processing': 42,
#  'Scheme': 42,
#  'eCommerce Platforms': 42,
#  'Cookies': 42,
#  'Annual Report': 41,
#  'Electromechanics': 41,
#  'Routing Protocol': 41,
#  'Computer Vision': 40,
#  'Representational state transfer (REST)': 40,
#  'Part-of-speech (POS) Tagging': 40,
#  'Point of Sale (POS) Software': 40,
#  'JavaScript': 40,
#  'Authentication': 40,
#  'Cloud Platform': 40,
#  'Facilities Engineering': 40,
#  'Rapid Application Development': 39,
#  'Software Development Kit (SDK)': 39,
#  'Database Administration': 39,
#  'Scripting Language': 39,
#  'Pragmatics': 39,
#  'Content Management System (CMS)': 39,
#  'Private Equity': 39,
#  'Database Design': 39,
#  'Delegation': 39,
#  'Enterprise Software': 38,
#  'Anti Money Laundering': 38,
#  'Electromagnetism': 38,
#  'Data Reporting': 38,
#  'Environmental Engineering': 38,
#  'Sorting': 38,
#  'Audio': 38,
#  'NP Completeness': 38,
#  'Jin Chinese': 38,
#  'Data Preparation': 37,
#  'Google Analytics': 37,
#  'Systems Management': 37,
#  'Robot': 37,
#  'Venture Capital (VC)': 37,
#  'Cognitive': 37,
#  'Software Quality Assurance (SQA)': 37,
#  'Mechanics': 37,
#  'Quantitative Polymerase Chain Reaction (qPCR)': 36,
#  'Instagram': 36,
#  'Psychology': 36,
#  'Social Work': 36,
#  'QA Testing': 36,
#  'Financial Accounting': 36,
#  'Cloud Service': 36,
#  'Aviation': 36,
#  'Probability': 36,
#  'Predictive Analytics': 35,
#  'Human Resource Management': 35,
#  'SAS Statistical Analysis': 35,
#  'Accounting Standards': 35,
#  'Relational Database': 35,
#  'International Financial Reporting Standards (IFRS)': 35,
#  'Sales Management': 34,
#  'Machine Learning Algorithm': 34,
#  'International Trade': 34,
#  'RStudio': 34,
#  'IP Addressing': 34,
#  'Decimal': 34,
#  'Report Analysis': 34,
#  'Microsoft Visio': 34,
#  'Engineering Technology': 33,
#  'Marine Engineering': 33,
#  'International Finance': 33,
#  'Agile Software Development': 33,
#  'Materials Management': 33,
#  'Shortage': 33,
#  'macOS': 33,
#  'Application Security': 33,
#  'Database Management System': 33,
#  'File System': 33,
#  'Middleware': 33,
#  'MATLAB': 32,
#  'Geography': 32,
#  'Nutrition': 32,
#  'Statistical Model': 32,
#  'Clustering': 32,
#  'Management Accounting': 32,
#  'Malware Analysis': 32,
#  'Machining': 32,
#  'Digital Media': 31,
#  'Immunology': 31,
#  'Verification And Validation': 31,
#  'Cost Accounting': 31,
#  'Performing Art': 31,
#  'Corporate Finance': 31,
#  'Data Presentation': 30,
#  'Google Ads': 30,
#  'Graphic Design': 30,
#  'Complex Analysis': 30,
#  'Online Marketing': 30,
#  'Geometry': 30,
#  'Structural Engineering': 30,
#  'Investment Management': 29,
#  'Inference': 29,
#  'Network Service': 29,
#  'Inside Sales': 29,
#  'ISO 13485': 29,
#  'GUI Design': 29,
#  'Content Marketing': 29,
#  'Animation': 29,
#  'Capacity Management': 29,
#  'Ergonomics': 29,
#  'Search Engine Optimization (SEO)': 28,
#  'Food Science': 28,
#  'Nanotechnology': 28,
#  'Genomics': 28,
#  'Task Management': 28,
#  'CVS': 28,
#  'Exploit': 28,
#  'Resource Management': 28,
#  'User Experience Design': 28,
#  'French': 28,
#  'Geotechnical Engineering': 28,
#  'Hospitality': 28,
#  'PL': 28,
#  'Accounting Software': 28,
#  'Extensible Markup Language (XML)': 28,
#  'Network Access Control': 28,
#  'D3.js': 28,
#  'Pharmacodynamics (PD)': 27,
#  'Product Lifecycle Management (PLM)': 27,
#  'Production Set': 27,
#  'Optical System': 27,
#  'Azure Machine Learning': 27,
#  'Business Economics': 27,
#  'Tor': 27,
#  'Crisis Management': 27,
#  'Induction': 27,
#  'Computer Worm': 27,
#  'Certified Information Systems Auditor (CISA)': 27,
#  'Bond': 27,
#  'IP Routing': 27,
#  'Uncertainty': 26,
#  'Sports Engineering': 26,
#  'Operations Research': 26,
#  'Oncology': 26,
#  'Bioinformatics': 26,
#  'Biomaterials Engineering': 26,
#  'Social Security': 26,
#  'Natural Language Processing (NLP)': 26,
#  'Kanban': 26,
#  'Cisco Router': 26,
#  'Password': 26,
#  'Network Time Protocol (NTP)': 26,
#  'Public Policy': 25,
#  'Secure Socket Layer (SSL)': 25,
#  'PHP': 25,
#  'Clear Communication': 25,
#  'Localization': 25,
#  'Computing Technology': 25,
#  'Network Routing': 25,
#  'Music': 25,
#  'Process Control System': 25,
#  'Reliability Engineering': 25,
#  'LabVIEW': 24,
#  'Perceptron': 24,
#  'Sales Presentation': 24,
#  'Database System': 24,
#  'JavaScript Object Notation (JSON)': 24,
#  'Target Audience': 24,
#  'Journalism': 24,
#  'Underwriting': 24,
#  'Rendering': 24,
#  'Formatting': 24,
#  'Working Capital': 24,
#  'Certified Information Security Manager (CISM)': 24,
#  'IP Address': 24,
#  'Facebook Ads': 23,
#  'Digital Image': 23,
#  'Commercial Banking': 23,
#  'Content Management': 23,
#  'Microbiology': 23,
#  'Pharmaceutics': 23,
#  'Semantics': 23,
#  'Design Analysis': 23,
#  'Tracking System': 23,
#  'File Transfer Protocol (FTP)': 23,
#  'Cloud API': 23,
#  'Pharmacy': 22,
#  'Architectural Engineering': 22,
#  'Public Health': 22,
#  'Lead Generation': 22,
#  'Editor': 22,
#  'Apache Hadoop': 22,
#  'Distributed System': 22,
#  '3D Segmentation': 22,
#  'Entrepreneurship': 22,
#  'Ethernet': 22,
#  'National Account Systems (NAS)': 22,
#  'Microsoft Publisher': 21,
#  'Electronic and Electrical Engineering': 21,
#  'Photonics': 21,
#  'Differentiation': 21,
#  'Signal Processing': 21,
#  'Unity': 21,
#  'Foreign Language': 21,
#  'Streaming': 21,
#  'Property Management': 21,
#  'Angular': 21,
#  'Data Manipulation': 21,
#  'Social Media Platform': 21,
#  'Virtual Machine': 21,
#  'Tree': 21,
#  'Perl': 21,
#  'Arts': 20,
#  'Macroeconomics': 20,
#  'CODE V': 20,
#  'Market Research Analysis': 20,
#  'Programming Tool': 20,
#  'Version Control': 20,
#  'Image Processing': 20,
#  'Wage': 20,
#  'TikTok': 20,
#  'Emotional Intelligence (EQ)': 20,
#  'Data Capture': 20,
#  'Physical Security': 20,
#  'Performance Engineering': 20,
#  'Web Server': 20,
#  'Authentication Authorization And Accounting (AAA) Server': 20,
#  'Instrumentaion Engineering': 20,
#  'Wireless Network': 19,
#  'Therapy': 19,
#  'Growth Strategy': 19,
#  'Interest Rate': 19,
#  'Product Liability': 19,
#  'Marketing Channel': 19,
#  'Business Research': 19,
#  'Database Application': 19,
#  'Safety Engineering': 19,
#  'Access Control System': 19,
#  'Construction Engineering': 19,
#  'Aerospace Engineering': 19,
#  'Verilog': 18,
#  'Development Management': 18,
#  'SAS': 18,
#  'iland': 18,
#  'Optical Engineering': 18,
#  'Biomedical Engineering': 18,
#  'Economic Growth': 18,
#  'Geology': 18,
#  'Embedded System': 18,
#  'Aesthetics': 18,
#  'Venture Capiral': 18,
#  'Interaction Design': 18,
#  'Microsoft SQL Server': 18,
#  'Microsoft SQL Servers': 18,
#  'Enterprise System': 18,
#  'Git': 18,
#  'Financial Risk': 18,
#  'Intrusion Detection System': 18,
#  'SQL Server Integration Services (SSIS)': 18,
#  'Beaker': 18,
#  'Wireless LAN': 18,
#  'Anomaly Detection': 17,
#  'Talent Management': 17,
#  'Active Listening': 17,
#  'Environmental Science': 17,
#  'Supply and Demand': 17,
#  'Spring': 17,
#  'Statistical Modelling': 17,
#  'Animal Health': 17,
#  'Financial Engineering': 17,
#  'Phising': 17,
#  'Social Network': 17,
#  'Records Management': 17,
#  'Fund Accounting': 17,
#  'Business Continuity Planning': 17,
#  'Dance': 17,
#  'Bookkeeping': 16,
#  'Storytelling': 16,
#  'Predictive Modelling': 16,
#  'Chatbot': 16,
#  'Velocity': 16,
#  'Keras': 16,
#  'Brave': 16,
#  'Art History': 16,
#  'Graphical User Interface (GUI)': 16,
#  'Political Science': 16,
#  'Logical Data Models': 16,
#  'Apparel': 16,
#  'Mobile Development': 16,
#  'WebSphere': 16,
#  'Needs Analysis': 16,
#  'Unified Process (UP)': 16,
#  'Zoom': 16,
#  'Business Writing': 16,
#  'Solaris': 16,
#  'Casting': 16,
#  'Dependability': 15,
#  'Budget Planning': 15,
#  'Recommendation System': 15,
#  'Computer Programming': 15,
#  'Engineering Physics': 15,
#  'Urban Planning': 15,
#  'Energy Consumption': 15,
#  'Mobile Application Development': 15,
#  'Independent Component Analysis (ICA)': 15,
#  'Pandas': 15,
#  'Storage System': 15,
#  'Network Analysis': 15,
#  'Precision Time Protocol (PTP)': 15,
#  'Red Hat': 15,
#  'Apache Kafka': 15,
#  'Network Protocol': 15,
#  'Object-Oriented Programming (OOP)': 15,
#  'Spanish': 15,
#  'Hypertext Transfer Protocol (HTTP)': 15,
#  'Persuasion': 15,
#  'CMM': 15,
#  'Load Balancing': 15,
#  'Employee Development': 14,
#  'Storage Management': 14,
#  'Economic Development': 14,
#  'Power Systems Engineering': 14,
#  'Mathematics Foundations': 14,
#  'Office Management': 14,
#  'Economic Analysis': 14,
#  'UX Research': 14,
#  'Google Sheets': 14,
#  'Web Analytics': 14,
#  'Reverse Engineering': 14,
#  'Business Process Modelling': 14,
#  'Email Management': 14,
#  'Temporal Difference (TD) Learning': 14,
#  'Powershell': 14,
#  'Extreme Programming (XP)': 14,
#  'Jenkins': 14,
#  'Public Speaking': 14,
#  'Enhanced Interior Gateway Routing Protocol (EIGRP)': 14,
#  'Airlines': 13,
#  'Ensemble': 13,
#  'Scientific Method': 13,
#  'Qlik': 13,
#  'Food Production': 13,
#  'Semantic Technology': 13,
#  'Big Data Tool': 13,
#  'Game Design': 13,
#  'Recreation': 13,
#  'Copywriting': 13,
#  'Goods and Services': 13,
#  'Typography': 13,
#  'Shopify': 13,
#  'Adminitrative Assistance': 13,
#  'Algebra': 13,
#  'Cryptocurrency': 13,
#  'Investor Relations': 13,
#  'Property Management Software': 13,
#  'Online Business': 13,
#  'vSphere': 13,
#  'International Law': 13,
#  'RESTful API': 13,
#  'Pay-Per-Click (PPC) Marketing': 12,
#  'Agricultural Production': 12,
#  'Mathematical Economics': 12,
#  'Ecology': 12,
#  'Feature Engineering': 12,
#  'Data Science Tool': 12,
#  'Scikit-learn': 12,
#  'TensorFlow': 12,
#  'Computer-aided Design': 12,
#  'Conceptual Skills': 12,
#  'Google Workspace': 12,
#  'Tax Accounting': 12,
#  'Digital Communication': 12,
#  'PHP Development': 12,
#  'Construction Law': 12,
#  'Magento': 12,
#  'User Datagram Protocol (UDP)': 12,
#  'Value Stream Mapping': 12,
#  'Financial Risk Management': 12,
#  'Opportunity Cost': 12,
#  'Missing Data': 12,
#  'Infrastructure as Code (IaS)': 12,
#  'Network Optimization': 12,
#  'Landscape Architecture': 12,
#  'Patient Care': 11,
#  'Scaled Agile Framework (SAFe)': 11,
#  'Bioengineering': 11,
#  'React Native': 11,
#  'Customer Service System': 11,
#  'Google Cloud Platform (GCP)': 11,
#  'Adobe Photoshop': 11,
#  'Text Analysis': 11,
#  'Programming Model': 11,
#  'Television': 11,
#  'Credit Risk Analysis': 11,
#  'Infographics': 11,
#  'Rivest-Shamir-Adleman (RSA)': 11,
#  'Oracle Databases': 11,
#  'Sales Leadership': 11,
#  'Web Browser': 11,
#  'Key Management': 11,
#  'ISO 9000': 11,
#  'Property Maintenance': 11,
#  'Social Engineering': 11,
#  'Message Authentication Code (MAC)': 11,
#  'Tcl': 11,
#  'Polymer Engineering': 11,
#  'Applied Engineering': 11,
#  'Build Automation': 11,
#  'Recommendation Engine': 10,
#  'Responsive Design': 10,
#  'Analytical Chemistry': 10,
#  'OpticStudio': 10,
#  'Exploratory Analysis': 10,
#  'Consumer Behaviour': 10,
#  'Cold Calling': 10,
#  'Intellectual Property Law': 10,
#  'Information Science': 10,
#  'Financial Regulation': 10,
#  'Sports Coaching': 10,
#  'Channel Marketing': 10,
#  'Marketing Analytics': 10,
#  'Newsletters': 10,
#  'Motion Control': 10,
#  'Linguistics': 10,
#  'Business Consulting': 10,
#  'Interior Design': 10,
#  'Legal Management': 10,
#  'Parsing': 10,
#  'Capacity Utilization': 10,
#  'Route Management': 10,
#  'Sybase': 10,
#  'Slack': 10,
#  'User Interface Design': 10,
#  'Wireframing': 10,
#  'Adobe Illustrator': 10,
#  'Vmware ESXi': 10,
#  'Computing Platform': 9,
#  'Cooking': 9,
#  'Organic Chemistry': 9,
#  'Development Studies': 9,
#  'Amazon EMR': 9,
#  'Nursing': 9,
#  'Visual Communication': 9,
#  'Computer Architecture': 9,
#  'Forensic Accounting': 9,
#  'Professional Training': 9,
#  'Rehabilitation': 9,
#  'Dictionary': 9,
#  'Cardiology': 9,
#  'Project Chart': 9,
#  'Gate Array': 9,
#  'Software Process': 9,
#  'Content Strategy': 9,
#  'Concurrent System': 9,
#  'Visual Basic': 9,
#  'Advanced Persistent Threat (APT)': 9,
#  'Conflict Management': 9,
#  'QlikView': 9,
#  'Encoding': 9,
#  'Mandarin Chinese': 9,
#  'Software Maintenance': 9,
#  'Contact Manager': 9,
#  'Amazon S3': 9,
#  'Human-Computer Interaction (HCI)': 9,
#  'Pharmaceutical Manufacturing': 9,
#  'Thermodynamics': 9,
#  'Mining Engineering': 9,
#  'Code Version': 9,
#  'Kotlin': 9,
#  'Campaign Optimization': 8,
#  'Adobe Analytics': 8,
#  'Digital Marketing System': 8,
#  'Digital Art': 8,
#  'Sustainable Agriculture': 8,
#  'Quantitative Data Analysis': 8,
#  'Microeconomics': 8,
#  'Geographic Information System (GIS)': 8,
#  'Marketing Consulting': 8,
#  'Contract Research Organization (CRO)': 8,
#  'Revenue Recognition': 8,
#  'Anthropology': 8,
#  'Strategic Management': 8,
#  'Automotive Engineering': 8,
#  'Email Marketing': 8,
#  'Socioeconomics': 8,
#  'Precision Engineering': 8,
#  'Technology Management': 8,
#  'Probably Approximately Correct (PAC) Learning': 8,
#  'Urology': 8,
#  'Unix Shell': 8,
#  'Platform as a Service (PaaS)': 8,
#  'Factoring': 8,
#  'Textiles': 8,
#  'Communications Management': 8,
#  'Financial Statement Analysis': 8,
#  'Data Privacy Law': 8,
#  'CompTIA Security': 8,
#  'Income Statement': 8,
#  'Portuguese': 8,
#  'Online Media': 8,
#  'Gantt Chart': 8,
#  'Ruby on Rails': 8,
#  'Ethernet VPN (EVPN)': 8,
#  'Electromechanical Engineering': 8,
#  'ETAP': 8,
#  'Web Development Framework': 8,
#  'Genetic Engineering': 7,
#  'OpenStack': 7,
#  'Mathematical Physics': 7,
#  'Biostatistics': 7,
#  'Managerial Finance': 7,
#  'Security Assertion Markup Language (SAML)': 7,
#  'Oracle Cloud': 7,
#  'PyTorch': 7,
#  'Veterinary': 7,
#  'Free Hand': 7,
#  'Cybercrime': 7,
#  'Ansible': 7,
#  'Public Administration': 7,
#  'Naval Architecture': 7,
#  'Applicant Tracking System': 7,
#  'Operational Databases': 7,
#  'Build Tool': 7,
#  'Food Service Operations': 7,
#  'Data Transmission': 7,
#  'Atlassian': 7,
#  'Dash': 7,
#  'Logistic Engineering': 7,
#  ...}
